# %% [markdown]
# ## How to split by character
# This is the simplest method for splitting text. This splits based on a given character sequence, which defaults to "\n\n". Chunk length is measured by number of characters.
# How the text is split: by single character separator.
# How the chunk size is measured: by number of characters.
#
# To obtain the string content directly, use .splitText().

# %% [markdown]
# The output indicates that the CharacterTextSplitter is creating chunks larger than the specified chunk_size of 20 characters. This usually happens when the splitter cannot find the specified separator within the given chunk size, so it defaults to creating a larger chunk rather than arbitrarily cutting the text.

# %%
# Loading the document
from langchain_community.document_loaders import PyPDFLoader
text = PyPDFLoader('Cover.pdf')
documents = text.load()

# Extracting the text from the loaded documents
document_text = documents[0].page_content  # Assuming a single-page PDF

# Splitting the document into chunks using CharacterTextSplitter
from langchain.text_splitter import CharacterTextSplitter
chunks = CharacterTextSplitter(
    chunk_size=20,
    chunk_overlap=4,
    separator='and'  # Using newline as the separator
)

chunked_text = chunks.split_text(document_text)  # Split the single document's text
print(chunked_text[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Loading the document
#       2 from langchain_community.document_loaders import PyPDFLoader
# ----> 3 text = PyPDFLoader('Cover.pdf')
#       4 documents = text.load()
#       6 # Extracting the text from the loaded documents
#
# File c:\Users\bashi\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\document_loaders\pdf.py:182, in PyPDFLoader.__init__(self, file_path, password, headers, extract_images)
#     178 except ImportError:
#     179     raise ImportError(
#     180         "pypdf package not found, please install it with " "`pip install pypdf`"
#     181     )
# --> 182 super().__init__(file_path, headers=headers)
#     183 self.parser = PyPDFParser(password=password, extract_images=extract_images)
#
# File c:\Users\bashi\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_community\document_loaders\pdf.py:116, in BasePDFLoader.__init__(self, file_path, headers)
#     114         self.file_path = str(temp_pdf)
#     115 elif not os.path.isfile(self.file_path):
# --> 116     raise ValueError("File path %s is not a valid file or url" % self.file_path)
#
# ValueError: File path Cover.pdf is not a valid file or url

# %% [markdown]
# ## How to recursively split text by characters
# This text splitter is the recommended one for generic text. It is parameterized by a list of characters. It tries to split on them in order until the chunks are small enough. The default list is ["\n\n", "\n", " ", ""]. This has the effect of trying to keep all paragraphs (and then sentences, and then words)
# 1. How the text is split: by list of characters.
# 2. How the chunk size is measured: by number of characters.
#
# To obtain the string content directly, use .splitText.

# %%
pip install lnagchain langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement lnagchain (from versions: none)
# ERROR: No matching distribution found for lnagchain

# %%
# loading document
from langchain_community.document_loaders import TextLoader
myfile=TextLoader('text.txt')
loader=myfile.load()
loader()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 5
#       3 myfile=TextLoader('text.txt')
#       4 loader=myfile.load()
# ----> 5 loader()
#
# TypeError: 'list' object is not callable

# %%
from langchain_community.document_loaders import PyPDFLoader

# Load the PDF document
myfile = PyPDFLoader('samplepdf.pdf')
documents = myfile.load()

# Display the contents of the documents
for doc in documents:
    print(doc)
# Out:
# page_content='
# University Institute of Information Technology,
# PMAS -Arid Agriculture University,
# Rawalpindi Pakistan
#
# PhysioFlex -personal Posture Trainer
#
#
# By
#
# Hamza Akram         20-ARID -763
# M Fahad Bashir       20 -ARID -790
# Syeda Moniza           20 -ARID -833
#
#
# Supervisor
# Dr. Ruqia Bibi
# Bachelor of Science in Software Engineering  (2020-2024)
#  ' metadata={'source': 'samplepdf.pdf', 'page': 0}
# page_content='II
#
#
# The candidate confirms that the work submitted is their own and appropriate
#  credit has been given where reference has been made to the work of others .
#
# DECLARATION
#
# We hereby declare that this software, neither whole nor as a part has been copied out from any
# source. It is further declared that we have developed this software documentation and
# accompanied report entirely on the basis of our personal efforts. If any part of this project is
# proved to be copied out from any source or found to be reproduction of some other. We will
# stand by the consequences. No Portion of the work presented has been submitted of any
# application for any other degree or qualification of this or any other university or institute of
# learning.
#
# Muhammad Fahad Bashir                Hamza Akram                   Syeda Moniza
#
#                   ---------------------------                               ------------------                      --------------------
#
#
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 1}
# page_content='III
#  CERTIFICATE OF APPROVAL
#
# It is to certify that the final year project of BS (SE) “Physioflex -personal Posture Trainer” was
# developed by “Muhammad Fahad Bashir 20-Arid -790” , “Hamza Akram 20-Arid -763” and
# “Syeda Moniza  20-Arid -833” under the supervision of “Dr. Ruqia Bibi” and that in their
# opinion; it is fully adequate, in scope and quality for the degree of Bachelors of Science in
# Software Engineering.
#
#
#
#
# ---------------------------------------
# Supervisor
#
#
#
# ---------------------------------------
# (Mr. Imran Khurram)
# External Examiner
#
#
#
# ---------------------------------------
# DIRECTOR UIIT
#
#   ' metadata={'source': 'samplepdf.pdf', 'page': 2}
# page_content='IV
#  Executive Summary
#
# Our project address musculoskeletal health issues related to incorrect postures by introducing
# an innovative solution. The existing solutions in the field are criticized for lacking a
# comprehensive approach that integrates real -time posture detection with tailored exercise
# guidance. Many solutions that are excellent requires subscription. To fill this gap, our project
# aims to create a web application that serves  as a vigilant companion, continuously monitoring
# users' posture and providing immediate feedback on deviations from correct alignment.
#
# What distinguishes this project is its emphasis on personalization. The system is designed to
# offer a wide range of exe rcises tailored to each user's specific postural issues. By seamlessly
# integrating real -time posture detection with personalized guidance, users will have a powerful
# tool to rectify their posture habits and foster musculoskeletal health.
#
# The overarching g oal of this project is to enhance the quality of life for individuals by
# addressing the often overlooked aspect of posture. Through real -time monitoring and tailored
# guidance, the web application is poised to empower users to take proactive steps towards
# improving their musculoskeletal health.
#
#
#
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 3}
# page_content='V
#  Acknowledgement
#
# All praise is to Almighty Allah who bestowed upon us a minute portion of His boundless
# knowledge by virtue of which we were able to accomplish this challenging task.
# We are greatly indebted to our project supervisor “Dr. Ruqia Bibi” and our Co -Supervisor “Dr.
# Tariq Ali” for personal supervision, advice, valuable guidance and completion of this project.
# We are deeply indebted to him for encouragement and continual help during this work.
# And we ar e also thankful to our parents and family who have been a constant source of
# encouragement for us and brought us the values of honesty & hard work.
#
#
#
#
# Muhammad Fahad Bashir                      Hamza Akram             Syeda Moniza
#
# ---------------------------                        ---------------------------       ---------------------------
#
#
#
#
#
#
#
#
# Abbreviations  ' metadata={'source': 'samplepdf.pdf', 'page': 4}
# page_content='VI
#
# SRS  Software Requirement Specification
# PC Personal Computer
# SRE  Software Requirement Engineering
# SDLC  Software Development Lifecycle
#
#
#
#
#
#
#
#
#
#
#
# Table of Contents
#  ' metadata={'source': 'samplepdf.pdf', 'page': 5}
# page_content='VII
#  Introduction  ................................ ................................ ................................ ..............................  1
# 1.1 Brief  ................................ ................................ ................................ ...........................  1
# 1.2 Relevance to Course Modules  ................................ ................................ ...................  1
# 1.3 Project Background  ................................ ................................ ................................ .... 2
# 1.4 Literature Review ................................ ................................ ................................ ....... 3
# 1.5 Analysisi form Literature Review  ................................ ................................ ..............  3
# 1.6 Methodology and Software  Life Cycle  ................................ ................................ ..... 4
# Problem Definition  ................................ ................................ ................................ ...................  5
# 2.1 Problem Statement  ................................ ................................ ................................ ..... 5
# 2.2 Deliverable and Development Requirements  ................................ ............................  5
# 2.3 Current System ................................ ................................ ................................ ...........  6
# Requirement  Analysis  ................................ ................................ ................................ ..............  8
# 3.1 Functio nal Requirments  ................................ ................................ .............................  8
# 3.2 Non – Functional Requirments  ................................ ................................ ..................  8
# 3.2.1  Usability …………  ................................ ................................ ................................ . 8
# 3.2.2  Reliability  ................................ ................................ ................................ ...............  8
# 3.2.3  Performance  ................................ ................................ ................................ ...........  9
# 3.2.4  Supportability  ................................ ................................ ................................ .........  9
# 3.2.5  Design Constraints  ................................ ................................ ................................ . 9
# 3.2.6  Licensing Requirements ................................ ................................ .........................  9
# 3.3 Use case Model  ................................ ................................ ................................ ........  10
# 3.3.1  Use Case Diagarm ................................ ................................ ................................  10
# 3.3.2  Actors Discription  ................................ ................................ ................................  11
# 3.3.3  Use Case Discription ................................ ................................ ............................  11
#
# Design  and Architecture  ................................ ................................ ................................ ........  16
# 4.1 UML Structural Diagrams  ................................ ................................ .......................  16
# 4.1.1  Component Diagram  ................................ ................................ ............................  16
# 4.1.2  Deployment Diagram  ................................ ................................ ...........................  17
# 4.1.3  Class  Diagram  ................................ ................................ ................................ ..... 18 ' metadata={'source': 'samplepdf.pdf', 'page': 6}
# page_content='VIII
#  4.2 UML Structural Diagrams  ................................ ................................ .......................  19
# 4.2.1  DFD (Level 0)  Diagram  ................................ ................................ ......................  19
# 4.2.2  DFD (Level 1)  Diagram  ................................ ................................ .......................  19
# 4.3 UML Interaction  Diagrams  ................................ ................................ ......................  20
# 4.3.1  Sequence Diagrams  ................................ ................................ ..............................  20
#
# Implementation  ................................ ................................ ................................ ......................  21
# 5.1 Component Diagram  ................................ ................................ ...............................  21
# 5.2 Network and protocol choice  ................................ ................................ ...................  23
# 5.3 User Interface  ................................ ................................ ................................ ...........  24
#
# Testing and Evaluation  ................................ ................................ ................................ ..........  28
# 6.1 Verification  ................................ ................................ ................................ ..............  28
# 6.1.1  Functional Testing  ................................ ................................ ...............................  28
# 6.1.2  Static Testing  ................................ ................................ ................................ ....... 28
# 6.2 Validation  ................................ ................................ ................................ .................  28
# 6.3 Usability Testing  ................................ ................................ ................................ ...... 28
# 6.4 Unit Testing  ................................ ................................ ................................ .............  28
# 6.5 Test Cases for Managing Login Functionality  ................................ ..............................  29
# 6.6        Integration Testing ................................ ................................ ................................ .. 31
# 6.7        System Testing  ................................ ................................ ................................ ........  31
# 6.8        Acceptance Testing  ................................ ................................ ................................ . 31
# 6.9        Stress Testing ................................ ................................ ................................ ...........  31
# 6.10      Hardware Configuration for Tetsing  ................................ ................................ ...... 32
# 6.11      Evaluation  ................................ ................................ ................................ ................  32
# 6.12      Deployment  ................................ ................................ ................................ .............  33
# 6.13      Maintenance  ................................ ................................ ................................ ..............  34
# Conclusion and Future work  ................................ ................................ ...............................  36
# 7.1 Conclusion  ................................ ................................ ................................ ...............  36
# 7.2 Future Work  ................................ ................................ ................................ .............  36 ' metadata={'source': 'samplepdf.pdf', 'page': 7}
# page_content='IX
#  7.3 Refrence  ................................ ................................ ................................ ...................  36
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# List of Figures
#
# Fig 1.1 Block Diagram  ................................ ................................ ................................ ...............  7 ' metadata={'source': 'samplepdf.pdf', 'page': 8}
# page_content='X
#  Fig 3 .1 Use Case Diagram  ................................ ................................ ................................ ....... 10
# Fig 4.1 Component Diagram ................................ ................................ ................................ .... 16
# Fig 4.2 Deployment Diagram  ................................ ................................ ................................ .. 17
# Fig 4.3 Class Diagram ................................ ................................ ................................ ..............  18
# Fig 4.4 DFD (Level 0 ) Diagram  ................................ ................................ .............................  19
# Fig 4.5 DFD (Level 1)  Diagram  ................................ ................................ .............................  19
# Fig 4.6 Sequence  Diagram  ................................ ................................ ................................ ...... 20
# Fig 5.1 Home Page  ................................ ................................ ................................ ...................  26
# Fig 5.2  Main Sections  ................................ ................................ ................................ ..............  26
# Fig 5.3 Live Pose  ................................ ................................ ................................ .....................  27
# Fig 5.4 PhysioFlex Assitant  ................................ ................................ ................................ ..... 27
#
#
#
#
#
#
#
#
#
#
#
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 9}
# page_content='XI
#
#   List of Tables
# Table  3.1 Create Account  ................................ ................................ ................................ ....... 11
# Table  3.2 Log in  ................................ ................................ ................................ ......................  12
# Table  3.3 Browse Exercise and Training  ................................ ................................ ................  12
# Table  3.4 Search Exercise  ................................ ................................ ................................ ........  13
# Table  3.5 View Exercise Details  ................................ ................................ .............................  13
# Table  3.6 Start Training  ................................ ................................ ................................ ...........  14
# Table  3.7 Configure Training Session  ................................ ................................ ....................  14
# Table  3.8 Evaluate Session  ................................ ................................ ................................ ...... 15
# Table  3.9 Log Out  ................................ ................................ ................................ ...................  15
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 10}
# page_content='1
#  Chapter 1: Introduction
# Musculoskeletal health issues, often stemming from incorrect postures, are pervasive and can
# lead to discomfort and various health problems. This Final Year Project (FYP) endeavors to
# address this issue by introducing an innovative solution that combines real -time feedback and
# personalized exercise recommendations for postural correction.
#
# The existing solutions in the field lack a comprehensive approach that integrates real -time
# posture detection with tailored exercise guidance. Our project aims to bridge this gap by
# creating a web application that functions as a vigilant companion, continuously monitoring a
# user's posture and offering immediate feedback on any deviations from correct alignment.
#
# What sets this project apart is its emphasis on personalization. The system is designed to
# provide individualized exercise recommendations that cater to each user's unique postural
# issues. By seamlessly integratin g real -time posture detection with personalized guidance, users
# gain a powerful tool to rectify their posture habits and promote musculoskeletal health.
#
# The ultimate goal of this project is to enhance the quality of life for individuals by addressing
# an often overlooked aspect of their well -being posture. Through real -time monitoring and
# tailored guidance, this web application will empower users to take proactive steps towards
# improving their musculoskeletal health.
# 1.1.  Brief
# Our aim is to develop a web appli cation that focuses on musculoskeletal health. It aims to
# address posture -related issues by providing real -time posture feedback and personalized
# exercise recommendations to improve and maintain good posture. This will be implemented
# using technologies lik e TensorFlow.js.
# 1.2.  Relevance to Course Modules
# Our project is directly aligned with fundamental courses studied during our degree program,
# providing the essential knowledge and skills crucial for the successful development of our
# posture correction web appl ication.
#
# 1.2.1 Programming Fundamentals and Object -Oriented Programming:
# These courses have laid a robust foundation, particularly in the realm of back -end development
# where JavaScript serves as the primary language. The concepts acquired in programming
# fundamentals and object -oriented programming are fundamental to building the core
# functionality of our application.
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 11}
# page_content='2
#
# 1.2.2 Data Structures & Algorithms:
# Our proficiency in data structures and algorithms is pivotal in crafting efficient posture
# correction  algorithms. It empowers us to select appropriate data types and implement optimized
# solutions, ensuring the accuracy and effectiveness of our application.
#
# 1.2.3 Software Requirements Engineering:
# Software Requirements Engineering (SRE) has been a corners tone in our educational journey,
# imparting insights and techniques crucial for the conceptualization and construction of projects.
# The knowledge gained is invaluable in the initial phase of our project, where we gather
# requirements, ensuring alignment with  the real pain points of our target users.
#
# 1.2.4 Database:
# Databases, as the backbone of any web application or software, are addressed through our
# knowledge gained in this course. It equips us to design and implement a modern, fast, and
# reliable database , drawing upon fundamental concepts to ensure seamless data management
# within our application.
#
# 1.2.5 Software Quality Engineering:
# Our understanding of software quality engineering, encompassing testing methodologies and
# quality assurance, is instrumental  in maintaining high standards of quality for our application.
# It guides us in conducting various types of testing to deliver a reliable and high -quality product
# to our users.
#
# In summary, the knowledge and skills acquired in these courses directly contrib ute to the
# development and success of our posture correction web application. They provide the necessary
# tools and expertise to tackle the challenges associated with the project, ensuring that we deliver
# a robust and high -quality solution.
# 1.3.  Project Backgro und
# The inspiration for this project stems from a pressing need within the field of musculoskeletal
# health. Patients undergoing physiotherapy often face the challenge of maintaining proper
# posture, which is essential for their recovery and overall well -being. This need is particularly
# pronounced in cases where physiotherapists cannot be present at all times to provide real -time
# guidance and supervision.
#
# Furthermore, engaging a personal trainer or assistant for regular posture correction exercises
# can be b oth expensive and time -consuming. Many individuals with musculoskeletal issues find
# it difficult to access expert guidance consistently, limiting the effectiveness of their exercises.
#
# Recognizing these challenges, our project was conceived to bridge this  gap in patient care by
# developing a web application .We aim to provide an accessible and cost -effective solution.
# This application serves as a virtual assistant, offering continuous guidance and feedback to ' metadata={'source': 'samplepdf.pdf', 'page': 12}
# page_content='3
#  users, thereby helping them to rectify their pos ture issues and improve their musculoskeletal
# health, all while mitigating the difficulties and time constraints often associated with these
# endeavors.
# 1.4.  Literature Review
#
# 1.4.1 Research:
# Research on "Posture and Musculoskeletal Implications for Students Using Mobile Phones" is
# highly relevant in the context of the current trend of remote learning. This research can shed
# light on the impact of extended mobile phone use on posture and musculoskeletal health, which
# aligns with the concerns our project aims t o address.
# 1.4.2 Products:
# 1. "Wearable Posture Correction Devices" such as the Upright GO 2 Premium are examples of
# products that are gaining popularity. These devices provide real -time feedback and reminders
# to users, helping them maintain proper postur e. Mentioning specific products like this
# demonstrates the practical applications of posture correction technology.
# 2. "User -centric Applications" that focus on customization and personalized exercise plans are
# in line with the user -centered approach we ai m to adopt in our project. This trend emphasizes
# the importance of engaging users actively in their posture correction efforts.
# 3. The idea of "Building a Poor Body Posture Detection & Alert System" aligns with the core
# objective of our project, which is t o develop a real -time posture monitoring and correction
# system. This could serve as a relevant research direction and product concept for your literature
# review.
# 1.5. Analysis from Literature Review
# After reading the above literature reviews and viewing t he products come to conclusion that
# there is need for a solutions that is friendly and have real updates. Many products and services
# like Phio need subscription and difficult to get access. We have to get program code. Apps like
# Total Rehab only provides c linical video demo and required subscription.
# 1.6. Methodology and Software Lifecycle for This Project
# For our project, we have chosen the agile methodology as the foundation for our software
# development process. Agile is a dynamic and iterative appr oach that promotes flexibility and
# adaptability, making it particularly suitable for our project's nature. Here's how we plan to
# implement Agile for our software development life cycle (SDLC):  ' metadata={'source': 'samplepdf.pdf', 'page': 13}
# page_content='4
#  Agile Methodology:
# 1. Iterative and Incremental Development: We will break the project into small, manageable
# increments or sprints. Each sprint will focus on specific features or functionalities.
# 2. Collaborative Teamwork : Agile encourages close collaboration among team members,
# including developers, designers, and d omain experts. We will work closely with
# physiotherapists and potential users to ensure that the application meets their needs effectively.
# 3. Customer -Centric Approach:  Agile places a strong emphasis on customer feedback. We
# will regularly demonstrate the  application to users, gather their feedback, and use it to refine
# the features and functionalities, ensuring that the end product is aligned with user expectations.
# 4. Flexibility and Adaptability: Agile allows us to adapt to changing requirements or insi ghts
# throughout the project. As we delve deeper into the development process, we can adjust our
# priorities and approaches as needed to achieve the best possible outcomes.
# 5. Continuous Testing and Quality Assurance: Quality is paramount, and Agile integrat es
# testing into every phase of development. This ensures that the application remains stable and
# reliable at all times.
#
# By adopting the agile methodology, we intend to create a responsive and user -centric posture
# correction web application. The Agile prin ciples of collaboration, flexibility, and continuous
# improvement are vital in addressing the evolving needs of physiotherapist patients and
# providing a solution that is not only effective but also adaptable to changing requirements and
# user expectations.
# 1.6.1. Rationale behind Selected Methodology
# We selected the Agile methodology and a corresponding software development life cycle
# (SDLC) due to their adaptability and user -centric approach. Agile's flexibility allows us to
# respond to changing requirements and gather continuous user feedback. The chosen SDLC
# aligns with Agile's iterative development, ensuring incremental progress and regular testing to
# maintain high -quality standards. Both methodologies are well -suited for our posture correction
# project, ena bling us to create an effective, user -driven solution that addresses evolving needs
# in musculoskeletal health.
#
#
#
#
#
#  Chapter 2: Problem Definition  ' metadata={'source': 'samplepdf.pdf', 'page': 14}
# page_content='5
#  2.1. Problem Statement
# In the field of musculoskeletal health, there exists a significant challenge related to maintaining
# correct postures, especially for patients undergoing physiotherapy. Incorrect postures can
# hinder the healing process, lead to discomfort, and contribute to long -term health issues. The
# current solutions often lack the integration of real -time posture detection and personalized
# exercise guidance, making it difficult for individuals to receive immediate feedback and
# tailored recommendations to rectify their posture habits. This deficiency in the current
# approach creates a pressing need for a s olution that offers real -time posture monitoring and
# personalized exercise recommendations, addressing the pain points of physiotherapist patients
# and others seeking to improve their posture.
# 2.2. Deliverables and Development Requirements
# 2.2.1 Deliverable s:
#
# 1.  Posture Correction Web Application: The primary deliverable is a fully functional web
# application that provides real -time posture monitoring and personalized exercise
# recommendations. Users should be able to access and use this application seamlessly.
#
# 2.  User Documentation : Clear and comprehensive user documentation, including guides and
# tutorials on how to use the application effectively.
#
# 3.  System Documentation : In-depth system documentation detailing the application's
# architecture, codebase, and any APIs used.
#
# 4. Testing and Quality Assurance Reports : Documentation of rigorous testing and quality
# assurance efforts, ensuring the application's reliability and accuracy.
#
#
# 5. Maintenance and Support Plan: A plan outlining ongoing maintenance, updates, and u ser
# support to ensure the application remains effective and up -to-date.
#
#
# 2.2.2 Development Requirements:
#
# 1. Programming Languages : Proficiency in web development languages such as JavaScript,
# HTML, and CSS is essential. Additional skills in Python or oth er languages may be required
# for backend development.
#
# 2. Frontend Development: Expertise in frontend frameworks like React for creating the user
# interface and ensuring a user -friendly experience.
#  ' metadata={'source': 'samplepdf.pdf', 'page': 15}
# page_content='6
#  3. Backend Development:  Competence in backend technologies  like Node.js, Express, and
# databases (e.g., MongoDB) for handling data and real -time monitoring.
#
# 4. Machine Learning and AI:  Knowledge of machine learning algorithms for posture
# detection and AI for personalized exercise recommendations.
#
# 5. Database Management:  Skills in designing, implementing, and maintaining databases to
# store user data and posture information.
#
# 6. Security Measures : Implementation of robust security measures to protect user data and
# ensure compliance with privacy regulations.
#
# 7. User Experience (UX) Design : Incorporation of effective UX design principles to create an
# intuitive and engaging interface.
#
# 8. Testing and Quality Assurance : Rigorous testing methodologies to ensure the application's
# reliability, accuracy, and overall qua lity.
#
# These Deliverables and development requirements are essential for the successful
# implementation of the posture correction web application, aligning with the project's goals and
# objectives.
# 2.3. Current System
# PhysiApp is the companion app to Phys t rack, the platform that lets healthcare providers such
# as physiotherapists create and prescribe clinical exercise programs and conduct Telehealth
# consultations.
# When you use PhysiApp, your healthcare provider can accurately monitor your progress and
# feedba ck, allowing them to provide better support based on real data. Clinical studies confirm
# that apps like ours can help improve outcomes for patients.
#  ' metadata={'source': 'samplepdf.pdf', 'page': 16}
# page_content='7
#
#
# Figure 1.1: PhysiApp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 17}
# page_content='8
#  Chapter 3: Requirement Analysis
# 3.1. Functional Requirements
# Following are the functional requirements for our project.
#
# User Authentication and Profile Management:
# The system shall provide secure user authentication, allowing users to create accounts and log
# in securely. Users should have th e capability to create and manage personalized profiles,
# including essential details and preferences.
#
# Real -time Posture Monitoring:
# The application shall employ real -time posture detection mechanisms, utilizing camera inputs
# to continuously monitor the us er's posture. The system should provide immediate feedback to
# the user regarding deviations from correct posture alignment.
#
# Personalized Exercise Recommendations:
# The application shall offer tailored exercise recommendations based on the user's unique
# postural issues. These exercise recommendations should be adaptive, evolving as the user
# progresses in their posture correction journey.
#
# Data Storage and Management:
# The application shall securely store user data, including posture history and exercise
# preferences. Data management should adhere to privacy and security standards, with robust
# backup and recovery mechanisms in place.
#
# Exercise Selection and Customization:
# The system shall provide users with a diverse catalog of posture correction exercises,
# categorizing them based on specific purpose .Users should have the capability to select
# exercises based on personal preferences, allowing for a customizable and engaging workout
# routine.
# The application shall offer detailed descriptions and visual guides for each exercise, aiding
# users in understanding and performing them accurately.
#
# 3.2. Non -Functional Requirements
#   3.2.1. Usability:
# The user interface shall adhere to established design principles, ensuring an intuitive and
# visually appealing experience .
#
#  3.2.2. Reliability:
# The system shall incorporate effective error handling mechanisms to provide users with clear
# and informative error messages.  ' metadata={'source': 'samplepdf.pdf', 'page': 18}
# page_content='9
#
# 3.2.3. Performance:
# The application shall respond to user inputs within 3 seconds to ensure a seamless and
# responsive user experience.
# 3.2.4.  Supportability:
# It should be designed with robust Supportability features to ensure ease of maintenance,
# updates, and troubleshooting. This includes:
# Modularity: The system should be modular, allowing for straightforward  updates and
# modifications to individual components without affecting the entire application.
# Documentation: Comprehensive documentation for system architecture, code base, and APIs
# should be provided to facilitate efficient troubleshooting, updates, and f uture development.
# User Support: A user -friendly support system, including FAQs, user guides, and a responsive
# help desk, should be in place to assist users with any queries or issues.
# 3.2.5. Design Constraints
# Browser Compatibility: The application should  be compatible with major web browsers such
# as Chrome, Firefox, Safari, and Edge to ensure a consistent user experience.
# Network Requirements: The application should perform optimally under standard internet
# connectivity conditions, accommodating users wit h varying network speeds.
#
# 3.2.6. Licensing Requirements
# The posture correction web application will adhere to the following licensing requirements:
# Open Source Licensing: The application will be released under an open -source license,
# providing users with  the freedom to view, modify, and distribute the source code.
# Commercial Use: Users will be permitted to use the application for both personal and
# commercial purposes, encouraging widespread adoption.
# Compatibility: The selected license should be compatibl e with other open -source licenses to
# promote collaboration within the development community.  ' metadata={'source': 'samplepdf.pdf', 'page': 19}
# page_content='10
#  3.3. Use Cases Model
#
#
#
#                                                         Fig 3.1: Use Case Diagram
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 20}
# page_content='11
#  3.4. Actors  Description:
#  Primary Actors:
# The primary actor is the end -user who interacts directly with the posture correction web
# application. Users engage in activities such as logging in, monitoring their posture in real -time,
# receiving feedback, selecting exercises, and viewin g progress. The user is the focal point of the
# system and directly benefits f rom the application's features.
#  Secondary Actor:
# An administrator may be considered as a secondary actor responsible for managing system
# settings, user accounts, and ensuring the  overall functionality and security of the posture
# correction web application.
#
# 3.5. Use cases Description
# Use cases are a widely used and highly regarded format for capturing requirements.
#
# Use Case ID:   UC-1.2.1
# Use Case Name:  Create Account
# Actors:  Patient
# Description:  This use case involves the process of registering and creating a user
# account within the system.
#
# Trigger:  The user wants to create a new account.
#
#     Preconditions:  The user is not logged in and does not have an existing account.
# Post conditions : The user's account is successfully created.
# Normal Flow:  The user accesses the registration page.
# The user provides the necessary information, including username,
# email, and password.
# The system validates the information. The  system creates a new user
# account.
# The system sends a confirmation or welcome email to the user.
#
# Exceptions:  If the provided information is incomplete or invalid, the system
# displays an error message and does not create the account.
# Assumptions:  The us er has access to a valid email address for account verification.
#
# Table 3.1: Create Account
#
#
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 21}
# page_content='12
#
# Use Case ID:   UC-1.2.2
# Use Case Name:  Log In
# Actors:  Patient
# Description:  This use case allows the user to access their account by providing valid
# credentials.
#
# Trigger:  The user wants to log in.
#     Preconditions:  The user has a registered account.
#
# Post conditions : The user is successfully logged into their account.
#
# Normal Flow:  The user accesses the login page.
# The user enters their username or email and password.
# The system validates the credentials.
# If the credentials are valid, the user is logged into their account.
#
# Exceptions:  If the credentials are invalid, the system provides an error message,
# and the user is not logged in.
# Assumption s: The user remembers their login credentials.
# Table 3.2: Log in
#
#
# Use Case ID:   UC-1.2.3
# Use Case Name:  Browse Exercise and Training
# Actors:  Patient
# Description:  This use case allows the user to explore the available exercises and
# training materials.
# Trigger:  The user wants to browse and explore exercises and training options
# The user wants to end their current session and log out.
#     Preconditions:  The user is logged in to their account.
# Post conditions : The user can view available exercises and programs.
# Normal Flow:  The user navigates to the "Browse Exercises and Training" section.
# The system displays a list of available exercises and training
# programs.
# The user can click on an exercise or program to view more details.
#
# Exceptions:  None
# Assumptions:  The user is interested in exploring available exercises and training
# sessions.
# Table 3.3: Browse Exercise and Training
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 22}
# page_content='13
#
# Use Case ID:   UC-1.2.4
# Use Case Name:  Search Exercises
# Actors:  Patient
# Description:  This use case allows the user to search specific exercise that is
# recommended by the doctor.
#
# Trigger:  The user intends to find specific exercises.
#
#     Preconditions:  The user is logged into their account and is on the "Browse Exercises
# and Training" section.
# Post conditions:  The user  receives search results for specific exercises.
# Normal Flow:  The user uses a search feature to input keywords, exercise names, or
# other search criteria.
# The system processes the search query and provides a list of
# exercises that match the search criteria.
# The user can click on a specific exercise from the search results to
# view more details.
#
# Exceptions:  If there are no search result, system will notifies the user with an
# appropriate message.
# Assumptions:  The user is looking for specific exercis es and uses the search feature
# accordingly.
# Table 3.4: Search Exercise
#
# Use Case ID:   UC-1.2.5
# Use Case Name:  View Exercise Details
# Actors:  Patient
# Description:  This use case allows the user to view exercises details. View Exercise
# Details could be seen as an optional extension of “View Exercise
# History”. This means that while viewing exercise history, the user can
# optionally choose to view additional details for a specific exercise.
#
# Trigger:  The user wants to learn more about a particular exercise .
#     Preconditions:  The user is logged in and has selected specific exercise.
# Post conditions:  The user views detail information of specific exercise.
# Normal Flow:  The user selects a specific exercise from the list of available
# exercises.
# The system displays comprehensive exercise information, including
# step by step instructions, images, videos, recommended sets, and
# repetitions.
#
# Exceptions:  If exercise details are unavailable, system will notifies the user.
# Assumptions:  The user is interested in l earning about a specific exercise and intends
# to follow it.
# Table 3.5: View Exercise Details  ' metadata={'source': 'samplepdf.pdf', 'page': 23}
# page_content='14
#
#
# Use Case ID:   UC-1.2.6
# Use Case Name:  Start Training
# Actors:  Patient
# Description:  This use case allows the user to start their exercise session.
#
# Trigger:  The user is ready to start a training session.
#
#     Preconditions:  The user is logged into their account and has selected a training
# program or exercise.
# Post conditions:  The user completes the training session and progress is recorded.
# Normal Flow:  The user selects a training program or a specific exercise they wish
# to perform.
# The system provides instructions and sets a workout timer.
# The user follows the instructions and performs the exercises.
# The system tracks the progress and records the session, i ncluding
# completion status and performance metrics.
# Exceptions:  If there are technical issues or interruptions during the session, the
# system provides an option to resume or restart.
# Assumptions:  The user is prepared to engage in training sessions and has selected
# program or exercise.
# Table 3.6: Start Training
#
# Use Case ID:   UC-1.2.7
# Use Case Name:  Configure Training Sessions
# Actors:  Database
# Description:  This composite use case involves configuring and conducting a
# training session for a patient, including the steps to view patient
# profile.
#
# Trigger:   It will determine when and how to initiate training sessions.
#     Preconditions:  The physiotherapist is logged into their account.
# The patient has a registered account.
#
# Post conditions:  The training session is successfully configured and completed
# Normal Flow:  The physiotherapist accesses the patient's profile.
# The system displays the patient's profile, including relevant health
# information.
# The physiotherapist initiates the training session.
# The system evaluates the training session.
#
# Exceptions:  If there are technical issues or data inaccuracies during the session,
# the physiotherapist can choose to reschedule or repeat the session.
# Assumptions:  The physiotherapist has the necessary credentials to access patient
# profiles and initiate sessions.
# The patient is present and ready for the training session.  ' metadata={'source': 'samplepdf.pdf', 'page': 24}
# page_content='15
#
# Table 3.7: Configure Training Session
#
# Use Case ID:   UC-1.2.8
# Use Case Name:  Evaluate Training  Sessions
# Actors:  Database
# Description:  This use case will evaluate the training session, verify movement and
# accuracy, visualize data.
#
# Trigger:  The system will access the effectiveness and progress of the training
# session.
#     Preconditions:  The training session has been completed.
# Relevant session data, such as patient performance and exercise
# information, is available.
# Post conditions:  The training sessions are evaluated and assessments results are
# recorded in the system.
# Normal Flow:  The system verifies movement and accuracy in real -time.
# The system visualizes data and progress for the patient and the
# physiotherapist.
# The system provides access to session data, including exercise
# performance, patient feedback, and any real -time movement an alysis.
# Exceptions:  If there are technical issues or data inaccuracies during the
# evaluation, the physiotherapist can choose to repeat the evaluation or
# contact technical support.
# Assumptions:  The system can evaluate and visualize training data effective ly.
# Table 3.8: Evaluate Sessions
# Use Case ID:   UC-1.2.9
# Use Case Name:  Log Out
# Actors:  Patient
# Description:  This use case allows the user to log out from the application.
#
# Trigger:  The user wants to end their current session and log out.
#     Preconditions:  The user is currently logged in to their account.
# Post conditions:  The user is successfully logged out and current session is terminated.
# Normal Flow:  The user clicks on the "Log Out" button or option.
# The system logs the user out.
# The user is redirected to the login or home page.
#
# Exceptions:  None
# Assumptions:  The user wishes to secure their account by logging out.
# Table 3.9: Log out  ' metadata={'source': 'samplepdf.pdf', 'page': 25}
# page_content='16
#  Chapter 4: Design and Architecture
# 4.1.  UML Structural Diagrams
# 4.1.1. Component Diagram:
#
#
#                                                            Fig 4.1: Component Diagram
#
#
#
#
#
#  4.1.2. Deployment Diagram:  ' metadata={'source': 'samplepdf.pdf', 'page': 26}
# page_content='17
#
#
#
#                                            Fig 4.2: Deployment Diagram
#
#
#
#
#
#
#
# 4.1.3. Class Diagram:  ' metadata={'source': 'samplepdf.pdf', 'page': 27}
# page_content='18
#
#                                                               Fig 4.3: Class Diagram
#
#
#
#
#
# ' metadata={'source': 'samplepdf.pdf', 'page': 28}
# page_content='19
#  4.2.   UML Structural Diagrams
#  4.2.1. DFD (Level 0 )  Diagram
#
#
#
#
#                                            Fig 4.4: DFD (Level 0) Diagram
#
#
#
#
#
# 4.2.2. DFD (Level 1) Diagram
#
#
#
#
#
#
#                                              Fig 4.5: DFD (Level 1) Diagram
#  ' metadata={'source': 'samplepdf.pdf', 'page': 29}
# page_content='20
#  4.3. UML Interaction Diagrams
#
#  4.3.1. Sequence Diagram
#
#
#
#                                                     Fig 4.6: Sequence Diagram
#  ' metadata={'source': 'samplepdf.pdf', 'page': 30}
# page_content='21
#  Chapter 5: Implementation
# 5.1. Component Diagram
#
#
#
#
# Front End (Software) Layer
#
# 1. Web Interface:
# This component refers to the graphical user interface (GUI) elements that users interact with,
# including buttons, forms, menus, and visual elements. It provides the means for users to
# register, log in, manage their profiles, and interact with the application's features.
#
# 2. User Registration:
# This functionality allows new users to create accou nts within the application. It typically
# involves collecting user information such as name, email, password, and possibly additional
# details for profile setup.
#
#
#
# 3. User Authentication:  ' metadata={'source': 'samplepdf.pdf', 'page': 31}
# page_content='22
#  User authentication verifies the identity of users during the login p rocess. It ensures that only
# authorized users with valid credentials can access the application and its functionalities.
#
# 4. User Login:
# User login enables registered users to access their accounts by providing their credentials
# (username/email and passwor d). Successful login grants access to personalized features and
# content.
#
# 5. User Profile Management:
# This component enables users to view and update their profile information, such as contact
# details, preferences, profile picture, and any additional setti ngs relevant to their experience
# within the application.
#
# 6. Computer Vision Integration:
# Computer vision integration refers to the incorporation of image processing and analysis
# algorithms within the application. This can include functionalities like post ure detection,
# analysis of user movements, and visual feedback based on captured data.
#
# 7. User Posture Tracking:
# User posture tracking involves monitoring and analyzing users' postures in real time or based
# on captured data. It may use computer vision techniques, sensors, or other technologies to
# assess posture correctness and provide feedback or guidance.
#
# Business Layer
#
# 1. AI Algorithms:
# This component encompasses the artificial intelligence (AI) algorithms used in the application,
# such as machine le arning models for posture analysis, personalized exercise recommendations,
# anomaly detection, and user behavior prediction.
#
# 2. User Management:
# User management functionalities handle user accounts, permissions, roles, and access control
# within the applica tion. It includes features for creating, updating, deleting user accounts,
# managing user sessions, and enforcing security policies.
#
# 3. Real -Time Feedback Mechanisms:
# Real-time feedback mechanisms provide immediate responses or notifications to users based
# on their interactions or system events. This can include feedback on posture correctness,
# exercise performance, progress updates, alerts for anomalies, and motivational messages.
#
#
#
# 4. Personalized Progress Tracking:  ' metadata={'source': 'samplepdf.pdf', 'page': 32}
# ...
# how posture detection integrates with exercise recommendation logic to provide personalized
# exercise plans, ensuring that feedback generation synchronizes with real -time posture
# monitoring to deliver accurate feedback, and validating data flow and communication between
# various parts of the application. This ensures that Physioflex operates cohesiv ely as a unified
# system, with data integrity maintained throughout different processes and interactions.
# 6.7. System Testing
# System testing in Physioflex evaluates the overall behavior, performance, and reliability of the
# application as a whole. This inclu des testing end to end user workflows, data processing
# capabilities, system responsiveness under different loads and scenarios, and ensuring system
# stability and resilience. It also includes performance testing to assess how Physioflex handles
# concurrent u ser interactions, heavy data processing loads, and peak usage periods without
# compromising performance or user experience.
# 6.8. Acceptance Testing
# Acceptance testing in Physioflex involves validating the application with real users, including
# individuals with musculoskeletal issues, physical therapists, and healthcare professionals. This
# includes gathering feedback, evaluating user satisfaction, and assessing whether Physioflex
# meets users' acceptance criteria and effectively addresses their musculoskeleta l health needs.
# It also helps to validate that Physioflex aligns with user expectations, delivers tangible benefits
# in improving posture and musculoskeletal health, and meets the desired standards for usability,
# functionality, and overall user experience.
# 6.9. Stress Testing
# Stress testing in Physioflex assesses the applications performance, scalability, and resilience
# under high load and stress conditions. This involves simulating heavy user traffic, data
# processing loads, concurrent user interactions, and  peak usage scenarios to identify
# performance bottlenecks, resource limitations, and system vulnerabilities. It ensures that
# Physioflex can handle increased user demand, data processing requirements, and system stress
# without downtime, performance degradat ion, or functional issues, thus ensuring a robust and
# reliable application for users.  ' metadata={'source': 'samplepdf.pdf', 'page': 41}
# page_content='32
#  6.10. Hardware Configuration for Testing
# Physioflex testing environment includes specific hardware configurations to replicate real -
# world usage scenarios accurately. This  may involve testing the application on devices with
# varying screen sizes, processing capabilities, input methods, and network conditions to validate
# cross -platform compatibility, performance optimization, and hardware compatibility.
# Hardware configuration  for testing ensures that Physioflex operates effectively on different
# devices, platforms, and environments, delivering consistent functionality and user experience
# across diverse hardware configurations.
# 6.11. Evaluation
# 1. Testing Metrics Analysis:
# Evalu ation involves analyzing various testing metrics collected during the testing phases, such
# as verification, validation, usability testing, performance testing, and user acceptance testing.
# Metrics may include accuracy rates of posture detection algorithms,  user satisfaction scores,
# system response times, error rates, and scalability metrics under stress testing conditions.
#
# 2. Identification of Issues and Gaps :
# Evaluation includes identifying any issues, bugs, or gaps discovered during testing. This
# involve s categorizing issues based on severity, impact on functionality, and user experience.
# Common issues may include algorithm inaccuracies in posture detection, usability challenges
# in navigating the interface, performance bottlenecks under heavy load, or com patibility issues
# across different devices.
#
# 3. Prioritization of Enhancements :
# Based on the evaluation findings, enhancements and improvements are prioritized to address
# identified issues and enhance Physio flex's functionality, usability, performance, an d reliability.
# Prioritization involves categorizing enhancements into critical, high -priority, medium -priority,
# and low -priority items based on their impact on user experience and application functionality.
#
# 4. Data -Driven Decision Making:
# Evaluation in Ph ysioflex emphasizes data -driven decision making, leveraging testing results,
# user feedback, and performance metrics to guide decision -making processes. This involves
# analyzing qualitative and quantitative data to make informed decisions about feature
# enhan cements, bug fixes, performance optimizations, and usability improvements.
#
# 5. Iterative Refinement Process:
# Evaluation drives an iterative refinement process in Physioflex, where identified issues are
# addressed, enhancements are implemented, and new features are added based on user needs
# and feedback. This iterative approach ensures continuous improvement and evolution of
# Physioflex to meet user expectations and industry standards.
# 6. User Feedback Incorporation:  ' metadata={'source': 'samplepdf.pdf', 'page': 42}
# page_content='33
#  It includes incorporating user feedbac k gathered during usability testing, acceptance testing,
# and beta testing phases. User feedback is valuable in understanding user preferences, pain
# points, and feature requests, guiding enhancements and updates to align Physioflex with user
# expectations an d preferences.
# 6.12. Deployment
# 1. Production Environment Setup:
# Deployment of Physioflex involves setting up the production environment, including
# configuring servers, databases, network infrastructure, and security measures. This ensures a
# robust and sec ure environment for hosting Physioflex and managing user data securely.
#
# 2. Quality Assurance Checks:
# Before deployment, quality assurance checks are conducted to ensure that Physioflex meets all
# quality standards, including functionality, performance, sec urity, and usability. This involves
# final testing and validation to confirm that all identified issues have been addressed, and the
# application is ready for production release.
#
# 3. Roll-out Strategy:
# A roll out strategy is defined for deploying Physioflex to users, healthcare providers, and
# stakeholders. This may include phased roll out to specific user groups, geographical regions,
# or targeted audiences to manage deployment risks, gather feedback, and ensure a smooth
# transition to the live environment.
#
# 4. Version Control and Release Management:
# Version control and release management processes are implemented to track changes, manage
# code versions, and ensure controlled deployment of updates and new features. This includes
# documenting release notes, manag ing dependencies, and coordinating release schedules to
# minimize disruptions and ensure compatibility.
#
# 5. Post -Deployment Monitoring :
# After deployment, ongoing monitoring and performance evaluation are conducted to assess
# Physio flex's performance in the production environment. This involves monitoring system
# health, user activity, performance metrics, error logs, and security incidents to detect and
# address any issues promptly.
#
# 6. User Training and Support:
# User training and support resources are provide d to users, healthcare providers, and
# administrators to familiarize them with Physio flex's features, functionalities, and best
# practices. This includes user guides, tutorials, help documentation, and access to technical
# support channels for assistance and  troubleshooting.
#
#
# 7. Continuous Improvement and Updates:  ' metadata={'source': 'samplepdf.pdf', 'page': 43}
# page_content='34
#  Deployment of Physioflex is followed by a commitment to continuous improvement and
# updates. This involves gathering user feedback, monitoring application performance,
# identifying areas for enhancem ent, and releasing updates, patches, and new features to enhance
# user experience, address emerging needs, and stay competitive in the market.
#
# 8. Compliance and Data Security:
# Deployment includes ensuring compliance with regulatory requirements, data protection laws,
# and industry standards related to healthcare data privacy and security. This includes
# implementing data encryption, access controls, audit trails, and security protocols to protect
# user data and maintain regulatory compliance.
# 6.13. Mainte nance
# 1. Bug Fixes and Issue Resolution:
# Continuous monitoring and addressing of bugs, errors, and issues reported by users or
# identified through monitoring systems. This includes prompt investigation, debugging, and
# deployment of fixes to maintain applica tion functionality and user experience.
#
# 2. Performance Monitoring and Optimization:
# Ongoing monitoring of application performance metrics such as response times, resource
# utilization, and system stability. Optimization efforts focus on improving performan ce,
# scalability, and efficiency through code optimizations, database tuning, and infrastructure
# upgrades as needed.
#
# 3. Security Updates and Vulnerability Management :
# Regular security assessments, vulnerability scans, and updates to protect against cyber s ecurity
# threats. This includes applying security patches, implementing security best practices, securing
# data transmission, and ensuring compliance with data protection regulations.
#
# 4. Data Management and Backup Strategies:
# Implementing data management pr actices to ensure data integrity, availability, and
# confidentiality. This includes regular data backups, disaster recovery planning, data retention
# policies, and data encryption to safeguard sensitive user information.
#
# 5. User Support and Training:
# Providing ongoing user support through help desk services, technical assistance, and
# troubleshooting guidance. User training materials, documentation, and resources are updated
# and maintained to help users navigate the application effectively and maximize its benefits.
#
#
#
#
# 6. Version Control and Release Management:  ' metadata={'source': 'samplepdf.pdf', 'page': 44}
# page_content='35
#  Managing version control for application updates, patches, and new releases. This includes
# maintaining a release schedule, documenting release notes, managing dependencies, and
# ensuring smooth de ployment of updates to minimize disruptions.
#
# 7. Feedback Collection and Analysis:
# Continuously gathering user feedback, feature requests, and suggestions for improvement.
# Feedback analysis informs prioritization of enhancements, usability improvements, an d new
# feature development to align the application with user needs and expectations.
#
# 8. Performance Testing and Monitoring:
# Conducting periodic performance testing and monitoring to assess application scalability,
# reliability, and responsiveness. This inc ludes load testing, stress testing, and performance
# tuning to maintain optimal performance under varying usage conditions.
#
# 9. User Engagement and Community Building:
# Engaging with users, stakeholders, and the healthcare community to foster a collaborative
# environment. This includes participation in user forums, community discussions, and feedback
# sessions to gather insights, build relationships, and promote user engagement with Physioflex.
#
# 10. Technology Upgrades and Innovation:
# Keeping abreast of technol ogical advancements, frameworks, and tools relevant to
# musculoskeletal health and digital healthcare. This includes evaluating new technologies,
# incorporating innovative features, and leveraging emerging trends to enhance Physio flex's
# capabilities and use r experience.
#
#
#   ' metadata={'source': 'samplepdf.pdf', 'page': 45}
# page_content='36
#  Chapter 7: Conclusion and Future Work
# 7.1. Conclusion
# Physioflex represents a groundbreaking advancement in addressing musculoskeletal health
# through technology -driven solutions. Its real -time posture feedback, personalized exercise
# recommendations, and user -centric design have led to tangible improvements in posture
# awareness, discomfort reduction, and overall well -being for users. By bridging the gap between
# technology and healthcare, Physioflex has not only empowered individuals to  take proactive
# steps towards better posture but has also contributed to a broader conversation on preventive
# care, digital wellness, and the integration of technology in promoting healthier lifestyles.
# Looking ahead, Physio flex's commitment to continuous  innovation, user engagement, and
# collaborative partnerships ensures a future where musculoskeletal health management is
# accessible, personalized, and impactful for users worldwide.
#
# 7.2. Future Work
# 1. Invest in further research and development to improve th e accuracy, sensitivity, and
# specificity of posture detection algorithms used in Physioflex. Explore machine learning
# techniques, data augmentation strategies, and sensor integration for more precise and
# comprehensive posture assessment.
# 2. Explore innovativ e feedback mechanisms, such as augmented reality (A visualizations,
# haptic feedback, or gamification elements, to enhance user engagement and effectiveness
# of posture correction cues).
# 3. Personalized Exercise Recommendations: Expand the range of personalized  exercise
# recommendations in Physioflex, incorporating diverse exercises targeting specific
# musculoskeletal issues, mobility challenges, and ergonomic adjustments.
# 4. Integration with Wearable Devices: Explore integration with wearable devices and sensors
# to capture real -time posture data, monitor physical activity levels, and provide
# personalized feedback and reminders for posture correction throughout the day.
# 5. Data Analytic and Insights: Leverage data analytic and machine learning techniques to
# derive action able insights from user data collected by Physioflex, enabling personalized
# interventions, trend analysis, and predictive modeling for musculoskeletal health
# outcomes.
# 6. Telehealth and Remote Monitoring: Explore opportunities for integrating Physioflex with
# telehealth platforms, enabling remote consultations, virtual coaching sessions, and
# continuous monitoring of users' progress in posture correction and exercise adherence.
# 7. Accessibility and Inclusivity Features: Enhance Physio flex's accessibility features to cater
# to diverse user needs, including support for different languages, accessibility settings for
# users with disabilities, and inclusive design principles for a broader user base.  ' metadata={'source': 'samplepdf.pdf', 'page': 46}
# page_content='37
#  8. Clinical Validation and Research Collaborations: Collaborate with health care institutions,
# research organizations, and clinical experts to validate the efficacy of Physioflex in clinical
# settings, conduct longitudinal studies on posture improvement outcomes, and contribute
# to evidence based practices in musculoskeletal health.
# 9. User Engagement and Education Initiatives: Launching user engagement campaigns,
# educational materials, and community initiatives to raise awareness about musculoskeletal
# health, promote healthy posture habits, and foster a supportive user community around
# Physioflex.
# 10. Scalability and Global Reach: Plan for scalability and global expansion of Physioflex,
# considering localization for different regions, compliance with international healthcare
# standards, and scalability of infrastructure to accommodate growing  user populations.
#
#
#
#
# 7.3. References
# i. https://play.google.com/store/apps/details?id=com.physitrack.physiapp HYPERLINK
# "https://play.google.com/store/apps/details?id=com.physitrack.physiapp&pli=1"
# ii. https://www.usa.edu/blog/virtual -physical -therapy/
# iii. https://my.clevelandclinic.org/health/treatments/physical -therapy
# iv. https://www.virtualphysicaltherapists.com/
#
#
#
#
#  ' metadata={'source': 'samplepdf.pdf', 'page': 47}

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Load the PDF document
myfile = PyPDFLoader('samplepdf.pdf')
documents = myfile.load()
documents
# Out:
# [Document(metadata={'source': 'samplepdf.pdf', 'page': 0}, page_content=' \nUniversity Institute of Information Technology,  \nPMAS -Arid Agriculture University,  \nRawalpindi Pakistan  \n \nPhysioFlex -personal Posture Trainer  \n \n \nBy \n \nHamza Akram         20-ARID -763 \nM Fahad Bashir       20 -ARID -790 \nSyeda Moniza           20 -ARID -833 \n \n \nSupervisor  \nDr. Ruqia Bibi  \nBachelor of Science in Software Engineering  (2020-2024) \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 1}, page_content='II \n  \n \nThe candidate confirms that the work submitted is their own and appropriate  \n credit has been given where reference has been made to the work of others . \n \nDECLARATION  \n \nWe hereby declare that this software, neither whole nor as a part has been copied out from any \nsource. It is further declared that we have developed this software documentation and \naccompanied report entirely on the basis of our personal efforts. If any part of this project is \nproved to be copied out from any source or found to be reproduction of some other. We will \nstand by the consequences. No Portion of the work presented has been submitted of any \napplication for any other degree or qualification of this or any other university or institute of \nlearning.  \n \nMuhammad Fahad Bashir                Hamza Akram                   Syeda Moniza  \n \n                  ---------------------------                               ------------------                      --------------------  \n \n \n \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 2}, page_content='III \n CERTIFICATE OF APPROVAL  \n \nIt is to certify that the final year project of BS (SE) “Physioflex -personal Posture Trainer” was \ndeveloped by “Muhammad Fahad Bashir 20-Arid -790” , “Hamza Akram 20-Arid -763” and \n“Syeda Moniza  20-Arid -833” under the supervision of “Dr. Ruqia Bibi” and that in their \nopinion; it is fully adequate, in scope and quality for the degree of Bachelors of Science in \nSoftware Engineering.  \n \n \n \n \n---------------------------------------  \nSupervisor  \n \n \n \n---------------------------------------  \n(Mr. Imran Khurram)  \nExternal Examiner  \n \n \n \n---------------------------------------  \nDIRECTOR UIIT  \n \n  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 3}, page_content="IV \n Executive Summary  \n \nOur project address musculoskeletal health issues related to incorrect postures by introducing \nan innovative solution. The existing solutions in the field are criticized for lacking a \ncomprehensive approach that integrates real -time posture detection with tailored exercise \nguidance. Many solutions that are excellent requires subscription. To fill this gap, our project \naims to create a web application that serves  as a vigilant companion, continuously monitoring \nusers' posture and providing immediate feedback on deviations from correct alignment.  \n \nWhat distinguishes this project is its emphasis on personalization. The system is designed to \noffer a wide range of exe rcises tailored to each user's specific postural issues. By seamlessly \nintegrating real -time posture detection with personalized guidance, users will have a powerful \ntool to rectify their posture habits and foster musculoskeletal health.  \n \nThe overarching g oal of this project is to enhance the quality of life for individuals by \naddressing the often overlooked aspect of posture. Through real -time monitoring and tailored \nguidance, the web application is poised to empower users to take proactive steps towards \nimproving their musculoskeletal health.  \n  \n \n \n \n "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 4}, page_content='V \n Acknowledgement  \n \nAll praise is to Almighty Allah who bestowed upon us a minute portion of His boundless \nknowledge by virtue of which we were able to accomplish this challenging task.  \nWe are greatly indebted to our project supervisor “Dr. Ruqia Bibi” and our Co -Supervisor “Dr. \nTariq Ali” for personal supervision, advice, valuable guidance and completion of this project. \nWe are deeply indebted to him for encouragement and continual help during this work.  \nAnd we ar e also thankful to our parents and family who have been a constant source of \nencouragement for us and brought us the values of honesty & hard work.  \n \n \n \n \nMuhammad Fahad Bashir                      Hamza Akram             Syeda Moniza  \n \n---------------------------                        ---------------------------       ---------------------------  \n \n \n \n \n \n  \n \n \nAbbreviations  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 5}, page_content='VI \n  \nSRS  Software Requirement Specification  \nPC Personal Computer  \nSRE  Software Requirement Engineering  \nSDLC  Software Development Lifecycle  \n \n \n \n \n \n \n \n \n \n \n \nTable of Contents  \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 6}, page_content='VII \n Introduction  ................................ ................................ ................................ ..............................  1 \n1.1 Brief  ................................ ................................ ................................ ...........................  1 \n1.2 Relevance to Course Modules  ................................ ................................ ...................  1 \n1.3 Project Background  ................................ ................................ ................................ .... 2 \n1.4 Literature Review ................................ ................................ ................................ ....... 3 \n1.5 Analysisi form Literature Review  ................................ ................................ ..............  3 \n1.6 Methodology and Software  Life Cycle  ................................ ................................ ..... 4 \nProblem Definition  ................................ ................................ ................................ ...................  5 \n2.1 Problem Statement  ................................ ................................ ................................ ..... 5 \n2.2 Deliverable and Development Requirements  ................................ ............................  5 \n2.3 Current System ................................ ................................ ................................ ...........  6 \nRequirement  Analysis  ................................ ................................ ................................ ..............  8 \n3.1 Functio nal Requirments  ................................ ................................ .............................  8 \n3.2 Non – Functional Requirments  ................................ ................................ ..................  8 \n3.2.1  Usability …………  ................................ ................................ ................................ . 8 \n3.2.2  Reliability  ................................ ................................ ................................ ...............  8 \n3.2.3  Performance  ................................ ................................ ................................ ...........  9 \n3.2.4  Supportability  ................................ ................................ ................................ .........  9 \n3.2.5  Design Constraints  ................................ ................................ ................................ . 9 \n3.2.6  Licensing Requirements ................................ ................................ .........................  9 \n3.3 Use case Model  ................................ ................................ ................................ ........  10 \n3.3.1  Use Case Diagarm ................................ ................................ ................................  10 \n3.3.2  Actors Discription  ................................ ................................ ................................  11 \n3.3.3  Use Case Discription ................................ ................................ ............................  11 \n \nDesign  and Architecture  ................................ ................................ ................................ ........  16 \n4.1 UML Structural Diagrams  ................................ ................................ .......................  16 \n4.1.1  Component Diagram  ................................ ................................ ............................  16 \n4.1.2  Deployment Diagram  ................................ ................................ ...........................  17 \n4.1.3  Class  Diagram  ................................ ................................ ................................ ..... 18 '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 7}, page_content='VIII \n 4.2 UML Structural Diagrams  ................................ ................................ .......................  19 \n4.2.1  DFD (Level 0)  Diagram  ................................ ................................ ......................  19 \n4.2.2  DFD (Level 1)  Diagram  ................................ ................................ .......................  19 \n4.3 UML Interaction  Diagrams  ................................ ................................ ......................  20 \n4.3.1  Sequence Diagrams  ................................ ................................ ..............................  20 \n \nImplementation  ................................ ................................ ................................ ......................  21 \n5.1 Component Diagram  ................................ ................................ ...............................  21 \n5.2 Network and protocol choice  ................................ ................................ ...................  23 \n5.3 User Interface  ................................ ................................ ................................ ...........  24 \n \nTesting and Evaluation  ................................ ................................ ................................ ..........  28 \n6.1 Verification  ................................ ................................ ................................ ..............  28 \n6.1.1  Functional Testing  ................................ ................................ ...............................  28 \n6.1.2  Static Testing  ................................ ................................ ................................ ....... 28 \n6.2 Validation  ................................ ................................ ................................ .................  28 \n6.3 Usability Testing  ................................ ................................ ................................ ...... 28 \n6.4 Unit Testing  ................................ ................................ ................................ .............  28 \n6.5 Test Cases for Managing Login Functionality  ................................ ..............................  29 \n6.6        Integration Testing ................................ ................................ ................................ .. 31 \n6.7        System Testing  ................................ ................................ ................................ ........  31 \n6.8        Acceptance Testing  ................................ ................................ ................................ . 31 \n6.9        Stress Testing ................................ ................................ ................................ ...........  31 \n6.10      Hardware Configuration for Tetsing  ................................ ................................ ...... 32 \n6.11      Evaluation  ................................ ................................ ................................ ................  32 \n6.12      Deployment  ................................ ................................ ................................ .............  33 \n6.13      Maintenance  ................................ ................................ ................................ ..............  34 \nConclusion and Future work  ................................ ................................ ...............................  36 \n7.1 Conclusion  ................................ ................................ ................................ ...............  36 \n7.2 Future Work  ................................ ................................ ................................ .............  36 '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 8}, page_content='IX \n 7.3 Refrence  ................................ ................................ ................................ ...................  36 \n \n \n \n \n \n \n \n \n \n \n \n \n \n \nList of Figures  \n \nFig 1.1 Block Diagram  ................................ ................................ ................................ ...............  7 '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 9}, page_content='X \n Fig 3 .1 Use Case Diagram  ................................ ................................ ................................ ....... 10 \nFig 4.1 Component Diagram ................................ ................................ ................................ .... 16 \nFig 4.2 Deployment Diagram  ................................ ................................ ................................ .. 17 \nFig 4.3 Class Diagram ................................ ................................ ................................ ..............  18 \nFig 4.4 DFD (Level 0 ) Diagram  ................................ ................................ .............................  19 \nFig 4.5 DFD (Level 1)  Diagram  ................................ ................................ .............................  19 \nFig 4.6 Sequence  Diagram  ................................ ................................ ................................ ...... 20 \nFig 5.1 Home Page  ................................ ................................ ................................ ...................  26 \nFig 5.2  Main Sections  ................................ ................................ ................................ ..............  26 \nFig 5.3 Live Pose  ................................ ................................ ................................ .....................  27 \nFig 5.4 PhysioFlex Assitant  ................................ ................................ ................................ ..... 27 \n \n \n \n \n \n \n \n \n \n \n \n \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 10}, page_content='XI \n  \n  List of Tables  \nTable  3.1 Create Account  ................................ ................................ ................................ ....... 11 \nTable  3.2 Log in  ................................ ................................ ................................ ......................  12 \nTable  3.3 Browse Exercise and Training  ................................ ................................ ................  12 \nTable  3.4 Search Exercise  ................................ ................................ ................................ ........  13 \nTable  3.5 View Exercise Details  ................................ ................................ .............................  13 \nTable  3.6 Start Training  ................................ ................................ ................................ ...........  14 \nTable  3.7 Configure Training Session  ................................ ................................ ....................  14 \nTable  3.8 Evaluate Session  ................................ ................................ ................................ ...... 15 \nTable  3.9 Log Out  ................................ ................................ ................................ ...................  15 \n \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 11}, page_content="1 \n Chapter 1: Introduction  \nMusculoskeletal health issues, often stemming from incorrect postures, are pervasive and can \nlead to discomfort and various health problems. This Final Year Project (FYP) endeavors to \naddress this issue by introducing an innovative solution that combines real -time feedback and \npersonalized exercise recommendations for postural correction.  \n \nThe existing solutions in the field lack a comprehensive approach that integrates real -time \nposture detection with tailored exercise guidance. Our project aims to bridge this gap by \ncreating a web application that functions as a vigilant companion, continuously monitoring a \nuser's posture and offering immediate feedback on any deviations from correct alignment.  \n \nWhat sets this project apart is its emphasis on personalization. The system is designed to \nprovide individualized exercise recommendations that cater to each user's unique postural \nissues. By seamlessly integratin g real -time posture detection with personalized guidance, users \ngain a powerful tool to rectify their posture habits and promote musculoskeletal health.  \n \nThe ultimate goal of this project is to enhance the quality of life for individuals by addressing \nan often overlooked aspect of their well -being posture. Through real -time monitoring and \ntailored guidance, this web application will empower users to take proactive steps towards \nimproving their musculoskeletal health.  \n1.1.  Brief  \nOur aim is to develop a web appli cation that focuses on musculoskeletal health. It aims to \naddress posture -related issues by providing real -time posture feedback and personalized \nexercise recommendations to improve and maintain good posture. This will be implemented \nusing technologies lik e TensorFlow.js.  \n1.2.  Relevance to Course Modules  \nOur project is directly aligned with fundamental courses studied during our degree program, \nproviding the essential knowledge and skills crucial for the successful development of our \nposture correction web appl ication.  \n \n1.2.1 Programming Fundamentals and Object -Oriented Programming:  \nThese courses have laid a robust foundation, particularly in the realm of back -end development \nwhere JavaScript serves as the primary language. The concepts acquired in programming \nfundamentals and object -oriented programming are fundamental to building the core \nfunctionality of our application.  \n \n "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 12}, page_content='2 \n  \n1.2.2 Data Structures & Algorithms:  \nOur proficiency in data structures and algorithms is pivotal in crafting efficient posture \ncorrection  algorithms. It empowers us to select appropriate data types and implement optimized \nsolutions, ensuring the accuracy and effectiveness of our application.  \n \n1.2.3 Software Requirements Engineering:  \nSoftware Requirements Engineering (SRE) has been a corners tone in our educational journey, \nimparting insights and techniques crucial for the conceptualization and construction of projects. \nThe knowledge gained is invaluable in the initial phase of our project, where we gather \nrequirements, ensuring alignment with  the real pain points of our target users.  \n \n1.2.4 Database:  \nDatabases, as the backbone of any web application or software, are addressed through our \nknowledge gained in this course. It equips us to design and implement a modern, fast, and \nreliable database , drawing upon fundamental concepts to ensure seamless data management \nwithin our application.  \n \n1.2.5 Software Quality Engineering:  \nOur understanding of software quality engineering, encompassing testing methodologies and \nquality assurance, is instrumental  in maintaining high standards of quality for our application. \nIt guides us in conducting various types of testing to deliver a reliable and high -quality product \nto our users.  \n \nIn summary, the knowledge and skills acquired in these courses directly contrib ute to the \ndevelopment and success of our posture correction web application. They provide the necessary \ntools and expertise to tackle the challenges associated with the project, ensuring that we deliver \na robust and high -quality solution.  \n1.3.  Project Backgro und \nThe inspiration for this project stems from a pressing need within the field of musculoskeletal \nhealth. Patients undergoing physiotherapy often face the challenge of maintaining proper \nposture, which is essential for their recovery and overall well -being. This need is particularly \npronounced in cases where physiotherapists cannot be present at all times to provide real -time \nguidance and supervision.  \n \nFurthermore, engaging a personal trainer or assistant for regular posture correction exercises \ncan be b oth expensive and time -consuming. Many individuals with musculoskeletal issues find \nit difficult to access expert guidance consistently, limiting the effectiveness of their exercises.  \n \nRecognizing these challenges, our project was conceived to bridge this  gap in patient care by \ndeveloping a web application .We aim to provide an accessible and cost -effective solution. \nThis application serves as a virtual assistant, offering continuous guidance and feedback to '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 13}, page_content='3 \n users, thereby helping them to rectify their pos ture issues and improve their musculoskeletal \nhealth, all while mitigating the difficulties and time constraints often associated with these \nendeavors.  \n1.4.  Literature Review  \n \n1.4.1 Research:  \nResearch on "Posture and Musculoskeletal Implications for Students Using Mobile Phones" is \nhighly relevant in the context of the current trend of remote learning. This research can shed \nlight on the impact of extended mobile phone use on posture and musculoskeletal health, which \naligns with the concerns our project aims t o address.  \n1.4.2 Products:   \n1. "Wearable Posture Correction Devices" such as the Upright GO 2 Premium are examples of \nproducts that are gaining popularity. These devices provide real -time feedback and reminders \nto users, helping them maintain proper postur e. Mentioning specific products like this \ndemonstrates the practical applications of posture correction technology.  \n2. "User -centric Applications" that focus on customization and personalized exercise plans are \nin line with the user -centered approach we ai m to adopt in our project. This trend emphasizes \nthe importance of engaging users actively in their posture correction efforts.  \n3. The idea of "Building a Poor Body Posture Detection & Alert System" aligns with the core \nobjective of our project, which is t o develop a real -time posture monitoring and correction \nsystem. This could serve as a relevant research direction and product concept for your literature \nreview.  \n1.5. Analysis from Literature Review  \nAfter reading the above literature reviews and viewing t he products come to conclusion that \nthere is need for a solutions that is friendly and have real updates. Many products and services \nlike Phio need subscription and difficult to get access. We have to get program code. Apps like \nTotal Rehab only provides c linical video demo and required subscription.  \n1.6. Methodology and Software Lifecycle for This Project        \nFor our project, we have chosen the agile methodology as the foundation for our software \ndevelopment process. Agile is a dynamic and iterative appr oach that promotes flexibility and \nadaptability, making it particularly suitable for our project\'s nature. Here\'s how we plan to \nimplement Agile for our software development life cycle (SDLC):  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 14}, page_content="4 \n Agile Methodology:  \n1. Iterative and Incremental Development: We will break the project into small, manageable \nincrements or sprints. Each sprint will focus on specific features or functionalities.  \n2. Collaborative Teamwork : Agile encourages close collaboration among team members, \nincluding developers, designers, and d omain experts. We will work closely with \nphysiotherapists and potential users to ensure that the application meets their needs effectively.  \n3. Customer -Centric Approach:  Agile places a strong emphasis on customer feedback. We \nwill regularly demonstrate the  application to users, gather their feedback, and use it to refine \nthe features and functionalities, ensuring that the end product is aligned with user expectations.  \n4. Flexibility and Adaptability: Agile allows us to adapt to changing requirements or insi ghts \nthroughout the project. As we delve deeper into the development process, we can adjust our \npriorities and approaches as needed to achieve the best possible outcomes.  \n5. Continuous Testing and Quality Assurance: Quality is paramount, and Agile integrat es \ntesting into every phase of development. This ensures that the application remains stable and \nreliable at all times.  \n \nBy adopting the agile methodology, we intend to create a responsive and user -centric posture \ncorrection web application. The Agile prin ciples of collaboration, flexibility, and continuous \nimprovement are vital in addressing the evolving needs of physiotherapist patients and \nproviding a solution that is not only effective but also adaptable to changing requirements and \nuser expectations.  \n1.6.1. Rationale behind Selected Methodology  \nWe selected the Agile methodology and a corresponding software development life cycle \n(SDLC) due to their adaptability and user -centric approach. Agile's flexibility allows us to \nrespond to changing requirements and gather continuous user feedback. The chosen SDLC \naligns with Agile's iterative development, ensuring incremental progress and regular testing to \nmaintain high -quality standards. Both methodologies are well -suited for our posture correction \nproject, ena bling us to create an effective, user -driven solution that addresses evolving needs \nin musculoskeletal health.  \n \n \n \n \n \n Chapter 2: Problem Definition  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 15}, page_content="5 \n 2.1. Problem Statement  \nIn the field of musculoskeletal health, there exists a significant challenge related to maintaining \ncorrect postures, especially for patients undergoing physiotherapy. Incorrect postures can \nhinder the healing process, lead to discomfort, and contribute to long -term health issues. The \ncurrent solutions often lack the integration of real -time posture detection and personalized \nexercise guidance, making it difficult for individuals to receive immediate feedback and \ntailored recommendations to rectify their posture habits. This deficiency in the current \napproach creates a pressing need for a s olution that offers real -time posture monitoring and \npersonalized exercise recommendations, addressing the pain points of physiotherapist patients \nand others seeking to improve their posture.  \n2.2. Deliverables and Development Requirements  \n2.2.1 Deliverable s: \n \n1.  Posture Correction Web Application: The primary deliverable is a fully functional web \napplication that provides real -time posture monitoring and personalized exercise \nrecommendations. Users should be able to access and use this application seamlessly.  \n \n2.  User Documentation : Clear and comprehensive user documentation, including guides and \ntutorials on how to use the application effectively.  \n \n3.  System Documentation : In-depth system documentation detailing the application's \narchitecture, codebase, and any APIs used.  \n \n4. Testing and Quality Assurance Reports : Documentation of rigorous testing and quality \nassurance efforts, ensuring the application's reliability and accuracy.  \n \n \n5. Maintenance and Support Plan: A plan outlining ongoing maintenance, updates, and u ser \nsupport to ensure the application remains effective and up -to-date.  \n \n \n2.2.2 Development Requirements:  \n \n1. Programming Languages : Proficiency in web development languages such as JavaScript, \nHTML, and CSS is essential. Additional skills in Python or oth er languages may be required \nfor backend development.  \n \n2. Frontend Development: Expertise in frontend frameworks like React for creating the user \ninterface and ensuring a user -friendly experience.  \n "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 16}, page_content="6 \n 3. Backend Development:  Competence in backend technologies  like Node.js, Express, and \ndatabases (e.g., MongoDB) for handling data and real -time monitoring.  \n \n4. Machine Learning and AI:  Knowledge of machine learning algorithms for posture \ndetection and AI for personalized exercise recommendations.  \n \n5. Database Management:  Skills in designing, implementing, and maintaining databases to \nstore user data and posture information.  \n \n6. Security Measures : Implementation of robust security measures to protect user data and \nensure compliance with privacy regulations.  \n \n7. User Experience (UX) Design : Incorporation of effective UX design principles to create an \nintuitive and engaging interface.  \n \n8. Testing and Quality Assurance : Rigorous testing methodologies to ensure the application's \nreliability, accuracy, and overall qua lity. \n \nThese Deliverables and development requirements are essential for the successful \nimplementation of the posture correction web application, aligning with the project's goals and \nobjectives.  \n2.3. Current System  \nPhysiApp is the companion app to Phys t rack, the platform that lets healthcare providers such \nas physiotherapists create and prescribe clinical exercise programs and conduct Telehealth \nconsultations.  \nWhen you use PhysiApp, your healthcare provider can accurately monitor your progress and \nfeedba ck, allowing them to provide better support based on real data. Clinical studies confirm \nthat apps like ours can help improve outcomes for patients.  \n "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 17}, page_content='7 \n \n \nFigure 1.1: PhysiApp  \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 18}, page_content="8 \n Chapter 3: Requirement Analysis  \n3.1. Functional Requirements  \nFollowing are the functional requirements for our project.  \n \nUser Authentication and Profile Management:  \nThe system shall provide secure user authentication, allowing users to create accounts and log \nin securely. Users should have th e capability to create and manage personalized profiles, \nincluding essential details and preferences.  \n \nReal -time Posture Monitoring:  \nThe application shall employ real -time posture detection mechanisms, utilizing camera inputs \nto continuously monitor the us er's posture. The system should provide immediate feedback to \nthe user regarding deviations from correct posture alignment.  \n \nPersonalized Exercise Recommendations:  \nThe application shall offer tailored exercise recommendations based on the user's unique \npostural issues. These exercise recommendations should be adaptive, evolving as the user \nprogresses in their posture correction journey.  \n \nData Storage and Management:  \nThe application shall securely store user data, including posture history and exercise \npreferences. Data management should adhere to privacy and security standards, with robust \nbackup and recovery mechanisms in place.  \n \nExercise Selection and Customization:  \nThe system shall provide users with a diverse catalog of posture correction exercises,  \ncategorizing them based on specific purpose .Users should have the capability to select \nexercises based on personal preferences, allowing for a customizable and engaging workout \nroutine.  \nThe application shall offer detailed descriptions and visual guides for each exercise, aiding \nusers in understanding and performing them accurately.  \n \n3.2. Non -Functional Requirements  \n  3.2.1. Usability:  \nThe user interface shall adhere to established design principles, ensuring an intuitive and \nvisually appealing experience . \n \n 3.2.2. Reliability:  \nThe system shall incorporate effective error handling mechanisms to provide users with clear \nand informative error messages.  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 19}, page_content='9 \n  \n3.2.3. Performance:  \nThe application shall respond to user inputs within 3 seconds to ensure a seamless and  \nresponsive user experience.  \n3.2.4.  Supportability:  \nIt should be designed with robust Supportability features to ensure ease of maintenance, \nupdates, and troubleshooting. This includes:  \nModularity: The system should be modular, allowing for straightforward  updates and \nmodifications to individual components without affecting the entire application.  \nDocumentation: Comprehensive documentation for system architecture, code base, and APIs \nshould be provided to facilitate efficient troubleshooting, updates, and f uture development.  \nUser Support: A user -friendly support system, including FAQs, user guides, and a responsive \nhelp desk, should be in place to assist users with any queries or issues.  \n3.2.5. Design Constraints  \nBrowser Compatibility: The application should  be compatible with major web browsers such \nas Chrome, Firefox, Safari, and Edge to ensure a consistent user experience.  \nNetwork Requirements: The application should perform optimally under standard internet \nconnectivity conditions, accommodating users wit h varying network speeds.  \n \n3.2.6. Licensing Requirements  \nThe posture correction web application will adhere to the following licensing requirements:  \nOpen Source Licensing: The application will be released under an open -source license, \nproviding users with  the freedom to view, modify, and distribute the source code.  \nCommercial Use: Users will be permitted to use the application for both personal and \ncommercial purposes, encouraging widespread adoption.  \nCompatibility: The selected license should be compatibl e with other open -source licenses to \npromote collaboration within the development community.  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 20}, page_content='10 \n 3.3. Use Cases Model  \n \n \n \n                                                        Fig 3.1: Use Case Diagram  \n \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 21}, page_content="11 \n 3.4. Actors  Description:  \n Primary Actors:  \nThe primary actor is the end -user who interacts directly with the posture correction web \napplication. Users engage in activities such as logging in, monitoring their posture in real -time, \nreceiving feedback, selecting exercises, and viewin g progress. The user is the focal point of the \nsystem and directly benefits f rom the application's features.  \n Secondary Actor:  \nAn administrator may be considered as a secondary actor responsible for managing system \nsettings, user accounts, and ensuring the  overall functionality and security of the posture \ncorrection web application.  \n \n3.5. Use cases Description  \nUse cases are a widely used and highly regarded format for capturing requirements.  \n \nUse Case ID:   UC-1.2.1  \nUse Case Name:  Create Account  \nActors:  Patient  \nDescription:  This use case involves the process of registering and creating a user \naccount within the system.  \n \nTrigger:  The user wants to create a new account.  \n \n    Preconditions:  The user is not logged in and does not have an existing account.  \nPost conditions : The user's account is successfully created.  \nNormal Flow:  The user accesses the registration page.  \nThe user provides the necessary information, including username, \nemail, and password.  \nThe system validates the information. The  system creates a new user \naccount.  \nThe system sends a confirmation or welcome email to the user.  \n \nExceptions:  If the provided information is incomplete or invalid, the system \ndisplays an error message and does not create the account.  \nAssumptions:  The us er has access to a valid email address for account verification.  \n \nTable 3.1: Create Account  \n \n \n \n "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 22}, page_content='12 \n  \nUse Case ID:   UC-1.2.2  \nUse Case Name:  Log In  \nActors:  Patient  \nDescription:  This use case allows the user to access their account by providing valid \ncredentials.  \n \nTrigger:  The user wants to log in.  \n    Preconditions:  The user has a registered account.  \n \nPost conditions : The user is successfully logged into their account.  \n \nNormal Flow:  The user accesses the login page.  \nThe user enters their username or email and password.  \nThe system validates the credentials.  \nIf the credentials are valid, the user is logged into their account.  \n \nExceptions:  If the credentials are invalid, the system provides an error message, \nand the user is not logged in.  \nAssumption s: The user remembers their login credentials.  \nTable 3.2: Log in  \n \n \nUse Case ID:   UC-1.2.3  \nUse Case Name:  Browse Exercise and Training  \nActors:  Patient  \nDescription:  This use case allows the user to explore the available exercises and \ntraining materials.  \nTrigger:  The user wants to browse and explore exercises and training options  \nThe user wants to end their current session and log out.  \n    Preconditions:  The user is logged in to their account.  \nPost conditions : The user can view available exercises and programs.  \nNormal Flow:  The user navigates to the "Browse Exercises and Training" section.  \nThe system displays a list of available exercises and training \nprograms.  \nThe user can click on an exercise or program to view more details.  \n \nExceptions:  None  \nAssumptions:  The user is interested in exploring available exercises and training \nsessions.  \nTable 3.3: Browse Exercise and Training  \n \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 23}, page_content='13 \n  \nUse Case ID:   UC-1.2.4  \nUse Case Name:  Search Exercises  \nActors:  Patient  \nDescription:  This use case allows the user to search specific exercise that is \nrecommended by the doctor.  \n \nTrigger:  The user intends to find specific exercises.  \n \n    Preconditions:  The user is logged into their account and is on the "Browse Exercises \nand Training" section.  \nPost conditions:  The user  receives search results for specific exercises.  \nNormal Flow:  The user uses a search feature to input keywords, exercise names, or \nother search criteria.  \nThe system processes the search query and provides a list of \nexercises that match the search criteria.  \nThe user can click on a specific exercise from the search results to \nview more details.  \n \nExceptions:  If there are no search result, system will notifies the user with an \nappropriate message.  \nAssumptions:  The user is looking for specific exercis es and uses the search feature \naccordingly.  \nTable 3.4: Search Exercise  \n \nUse Case ID:   UC-1.2.5  \nUse Case Name:  View Exercise Details  \nActors:  Patient  \nDescription:  This use case allows the user to view exercises details. View Exercise \nDetails could be seen as an optional extension of “View Exercise \nHistory”. This means that while viewing exercise history, the user can \noptionally choose to view additional details for a specific exercise.  \n \nTrigger:  The user wants to learn more about a particular exercise . \n    Preconditions:  The user is logged in and has selected specific exercise.  \nPost conditions:  The user views detail information of specific exercise.  \nNormal Flow:  The user selects a specific exercise from the list of available \nexercises.  \nThe system displays comprehensive exercise information, including \nstep by step instructions, images, videos, recommended sets, and \nrepetitions.  \n \nExceptions:  If exercise details are unavailable, system will notifies the user.  \nAssumptions:  The user is interested in l earning about a specific exercise and intends \nto follow it.  \nTable 3.5: View Exercise Details  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 24}, page_content="14 \n  \n \nUse Case ID:   UC-1.2.6  \nUse Case Name:  Start Training  \nActors:  Patient  \nDescription:  This use case allows the user to start their exercise session.  \n \nTrigger:  The user is ready to start a training session.  \n \n    Preconditions:  The user is logged into their account and has selected a training \nprogram or exercise.  \nPost conditions:  The user completes the training session and progress is recorded.  \nNormal Flow:  The user selects a training program or a specific exercise they wish \nto perform.  \nThe system provides instructions and sets a workout timer.  \nThe user follows the instructions and performs the exercises.  \nThe system tracks the progress and records the session, i ncluding \ncompletion status and performance metrics.  \nExceptions:  If there are technical issues or interruptions during the session, the \nsystem provides an option to resume or restart.  \nAssumptions:  The user is prepared to engage in training sessions and has selected \nprogram or exercise.  \nTable 3.6: Start Training  \n \nUse Case ID:   UC-1.2.7  \nUse Case Name:  Configure Training Sessions  \nActors:  Database  \nDescription:  This composite use case involves configuring and conducting a \ntraining session for a patient, including the steps to view patient \nprofile.  \n \nTrigger:   It will determine when and how to initiate training sessions.  \n    Preconditions:  The physiotherapist is logged into their account.  \nThe patient has a registered account.  \n \nPost conditions:  The training session is successfully configured and completed  \nNormal Flow:  The physiotherapist accesses the patient's profile.  \nThe system displays the patient's profile, including relevant health \ninformation.  \nThe physiotherapist initiates the training session.  \nThe system evaluates the training session.  \n \nExceptions:  If there are technical issues or data inaccuracies during the session, \nthe physiotherapist can choose to reschedule or repeat the session.  \nAssumptions:  The physiotherapist has the necessary credentials to access patient \nprofiles and initiate sessions.  \nThe patient is present and ready for the training session.  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 25}, page_content='15 \n  \nTable 3.7: Configure Training Session  \n \nUse Case ID:   UC-1.2.8  \nUse Case Name:  Evaluate Training  Sessions  \nActors:  Database  \nDescription:  This use case will evaluate the training session, verify movement and \naccuracy, visualize data.  \n \nTrigger:  The system will access the effectiveness and progress of the training \nsession.  \n    Preconditions:  The training session has been completed.  \nRelevant session data, such as patient performance and exercise \ninformation, is available.  \nPost conditions:  The training sessions are evaluated and assessments results are \nrecorded in the system.  \nNormal Flow:  The system verifies movement and accuracy in real -time.  \nThe system visualizes data and progress for the patient and the \nphysiotherapist.  \nThe system provides access to session data, including exercise \nperformance, patient feedback, and any real -time movement an alysis.  \nExceptions:  If there are technical issues or data inaccuracies during the \nevaluation, the physiotherapist can choose to repeat the evaluation or \ncontact technical support.  \nAssumptions:  The system can evaluate and visualize training data effective ly. \nTable 3.8: Evaluate Sessions  \nUse Case ID:   UC-1.2.9  \nUse Case Name:  Log Out  \nActors:  Patient  \nDescription:  This use case allows the user to log out from the application.  \n \nTrigger:  The user wants to end their current session and log out.  \n    Preconditions:  The user is currently logged in to their account.  \nPost conditions:  The user is successfully logged out and current session is terminated.  \nNormal Flow:  The user clicks on the "Log Out" button or option.  \nThe system logs the user out.  \nThe user is redirected to the login or home page.  \n \nExceptions:  None  \nAssumptions:  The user wishes to secure their account by logging out.  \nTable 3.9: Log out  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 26}, page_content='16 \n Chapter 4: Design and Architecture  \n4.1.  UML Structural Diagrams  \n4.1.1. Component Diagram:  \n \n                                    \n                                                           Fig 4.1: Component Diagram  \n \n \n \n \n \n 4.1.2. Deployment Diagram:  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 27}, page_content='17 \n \n \n \n                                           Fig 4.2: Deployment Diagram  \n \n \n \n \n \n \n \n4.1.3. Class Diagram:  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 28}, page_content='18 \n  \n                                                              Fig 4.3: Class Diagram  \n \n \n \n \n \n'),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 29}, page_content='19 \n 4.2.   UML Structural Diagrams  \n 4.2.1. DFD (Level 0 )  Diagram  \n \n \n \n \n                                           Fig 4.4: DFD (Level 0) Diagram  \n \n \n \n \n \n4.2.2. DFD (Level 1) Diagram  \n \n \n \n \n \n                                           \n                                             Fig 4.5: DFD (Level 1) Diagram  \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 30}, page_content='20 \n 4.3. UML Interaction Diagrams  \n \n 4.3.1. Sequence Diagram  \n \n \n \n                                                    Fig 4.6: Sequence Diagram  \n '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 31}, page_content="21 \n Chapter 5: Implementation  \n5.1. Component Diagram  \n \n \n                                                       \n                                     \nFront End (Software) Layer  \n \n1. Web Interface:  \nThis component refers to the graphical user interface (GUI) elements that users interact with, \nincluding buttons, forms, menus, and visual elements. It provides the means for users to \nregister, log in, manage their profiles, and interact with the application's features.  \n \n2. User Registration:  \nThis functionality allows new users to create accou nts within the application. It typically \ninvolves collecting user information such as name, email, password, and possibly additional \ndetails for profile setup.  \n \n \n \n3. User Authentication:  "),
# ...
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 42}, page_content="32 \n 6.10. Hardware Configuration for Testing  \nPhysioflex testing environment includes specific hardware configurations to replicate real -\nworld usage scenarios accurately. This  may involve testing the application on devices with \nvarying screen sizes, processing capabilities, input methods, and network conditions to validate \ncross -platform compatibility, performance optimization, and hardware compatibility. \nHardware configuration  for testing ensures that Physioflex operates effectively on different \ndevices, platforms, and environments, delivering consistent functionality and user experience \nacross diverse hardware configurations.  \n6.11. Evaluation  \n1. Testing Metrics Analysis:  \nEvalu ation involves analyzing various testing metrics collected during the testing phases, such \nas verification, validation, usability testing, performance testing, and user acceptance testing. \nMetrics may include accuracy rates of posture detection algorithms,  user satisfaction scores, \nsystem response times, error rates, and scalability metrics under stress testing conditions.  \n \n2. Identification of Issues and Gaps : \nEvaluation includes identifying any issues, bugs, or gaps discovered during testing. This \ninvolve s categorizing issues based on severity, impact on functionality, and user experience. \nCommon issues may include algorithm inaccuracies in posture detection, usability challenges \nin navigating the interface, performance bottlenecks under heavy load, or com patibility issues \nacross different devices.  \n \n3. Prioritization of Enhancements : \nBased on the evaluation findings, enhancements and improvements are prioritized to address \nidentified issues and enhance Physio flex's functionality, usability, performance, an d reliability. \nPrioritization involves categorizing enhancements into critical, high -priority, medium -priority, \nand low -priority items based on their impact on user experience and application functionality.  \n \n4. Data -Driven Decision Making:  \nEvaluation in Ph ysioflex emphasizes data -driven decision making, leveraging testing results, \nuser feedback, and performance metrics to guide decision -making processes. This involves \nanalyzing qualitative and quantitative data to make informed decisions about feature \nenhan cements, bug fixes, performance optimizations, and usability improvements.  \n \n5. Iterative Refinement Process:  \nEvaluation drives an iterative refinement process in Physioflex, where identified issues are \naddressed, enhancements are implemented, and new features are added based on user needs \nand feedback. This iterative approach ensures continuous improvement and evolution of \nPhysioflex to meet user expectations and industry standards.  \n6. User Feedback Incorporation:  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 43}, page_content="33 \n It includes incorporating user feedbac k gathered during usability testing, acceptance testing, \nand beta testing phases. User feedback is valuable in understanding user preferences, pain \npoints, and feature requests, guiding enhancements and updates to align Physioflex with user \nexpectations an d preferences.  \n6.12. Deployment  \n1. Production Environment Setup:  \nDeployment of Physioflex involves setting up the production environment, including \nconfiguring servers, databases, network infrastructure, and security measures. This ensures a \nrobust and sec ure environment for hosting Physioflex and managing user data securely.  \n \n2. Quality Assurance Checks:  \nBefore deployment, quality assurance checks are conducted to ensure that Physioflex meets all \nquality standards, including functionality, performance, sec urity, and usability. This involves \nfinal testing and validation to confirm that all identified issues have been addressed, and the \napplication is ready for production release.  \n \n3. Roll-out Strategy:  \nA roll out strategy is defined for deploying Physioflex to users, healthcare providers, and \nstakeholders. This may include phased roll out to specific user groups, geographical regions, \nor targeted audiences to manage deployment risks, gather feedback, and ensure a smooth \ntransition to the live environment.  \n \n4. Version Control and Release Management:  \nVersion control and release management processes are implemented to track changes, manage \ncode versions, and ensure controlled deployment of updates and new features. This includes \ndocumenting release notes, manag ing dependencies, and coordinating release schedules to \nminimize disruptions and ensure compatibility.  \n \n5. Post -Deployment Monitoring : \nAfter deployment, ongoing monitoring and performance evaluation are conducted to assess \nPhysio flex's performance in the production environment. This involves monitoring system \nhealth, user activity, performance metrics, error logs, and security incidents to detect and \naddress any issues promptly.  \n \n6. User Training and Support:  \nUser training and support resources are provide d to users, healthcare providers, and \nadministrators to familiarize them with Physio flex's features, functionalities, and best \npractices. This includes user guides, tutorials, help documentation, and access to technical \nsupport channels for assistance and  troubleshooting.  \n \n \n7. Continuous Improvement and Updates:  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 44}, page_content='34 \n Deployment of Physioflex is followed by a commitment to continuous improvement and \nupdates. This involves gathering user feedback, monitoring application performance, \nidentifying areas for enhancem ent, and releasing updates, patches, and new features to enhance \nuser experience, address emerging needs, and stay competitive in the market.  \n \n8. Compliance and Data Security:  \nDeployment includes ensuring compliance with regulatory requirements, data protection laws, \nand industry standards related to healthcare data privacy and security. This includes \nimplementing data encryption, access controls, audit trails, and security protocols to protect \nuser data and maintain regulatory compliance.  \n6.13. Mainte nance  \n1. Bug Fixes and Issue Resolution:  \nContinuous monitoring and addressing of bugs, errors, and issues reported by users or \nidentified through monitoring systems. This includes prompt investigation, debugging, and \ndeployment of fixes to maintain applica tion functionality and user experience.  \n \n2. Performance Monitoring and Optimization:  \nOngoing monitoring of application performance metrics such as response times, resource \nutilization, and system stability. Optimization efforts focus on improving performan ce, \nscalability, and efficiency through code optimizations, database tuning, and infrastructure \nupgrades as needed.  \n \n3. Security Updates and Vulnerability Management : \nRegular security assessments, vulnerability scans, and updates to protect against cyber s ecurity \nthreats. This includes applying security patches, implementing security best practices, securing \ndata transmission, and ensuring compliance with data protection regulations.  \n \n4. Data Management and Backup Strategies:  \nImplementing data management pr actices to ensure data integrity, availability, and \nconfidentiality. This includes regular data backups, disaster recovery planning, data retention \npolicies, and data encryption to safeguard sensitive user information.  \n \n5. User Support and Training:  \nProviding ongoing user support through help desk services, technical assistance, and \ntroubleshooting guidance. User training materials, documentation, and resources are updated \nand maintained to help users navigate the application effectively and maximize its benefits.  \n \n \n \n \n6. Version Control and Release Management:  '),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 45}, page_content="35 \n Managing version control for application updates, patches, and new releases. This includes \nmaintaining a release schedule, documenting release notes, managing dependencies, and \nensuring smooth de ployment of updates to minimize disruptions.  \n \n7. Feedback Collection and Analysis:  \nContinuously gathering user feedback, feature requests, and suggestions for improvement. \nFeedback analysis informs prioritization of enhancements, usability improvements, an d new \nfeature development to align the application with user needs and expectations.  \n \n8. Performance Testing and Monitoring:  \nConducting periodic performance testing and monitoring to assess application scalability, \nreliability, and responsiveness. This inc ludes load testing, stress testing, and performance \ntuning to maintain optimal performance under varying usage conditions.  \n \n9. User Engagement and Community Building:  \nEngaging with users, stakeholders, and the healthcare community to foster a collaborative  \nenvironment. This includes participation in user forums, community discussions, and feedback \nsessions to gather insights, build relationships, and promote user engagement with Physioflex.  \n \n10. Technology Upgrades and Innovation:  \nKeeping abreast of technol ogical advancements, frameworks, and tools relevant to \nmusculoskeletal health and digital healthcare. This includes evaluating new technologies, \nincorporating innovative features, and leveraging emerging trends to enhance Physio flex's \ncapabilities and use r experience.  \n \n \n  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 46}, page_content="36 \n Chapter 7: Conclusion and Future Work  \n7.1. Conclusion  \nPhysioflex represents a groundbreaking advancement in addressing musculoskeletal health \nthrough technology -driven solutions. Its real -time posture feedback, personalized exercise \nrecommendations, and user -centric design have led to tangible improvements in posture \nawareness, discomfort reduction, and overall well -being for users. By bridging the gap between \ntechnology and healthcare, Physioflex has not only empowered individuals to  take proactive \nsteps towards better posture but has also contributed to a broader conversation on preventive \ncare, digital wellness, and the integration of technology in promoting healthier lifestyles. \nLooking ahead, Physio flex's commitment to continuous  innovation, user engagement, and \ncollaborative partnerships ensures a future where musculoskeletal health management is \naccessible, personalized, and impactful for users worldwide.  \n \n7.2. Future Work  \n1. Invest in further research and development to improve th e accuracy, sensitivity, and \nspecificity of posture detection algorithms used in Physioflex. Explore machine learning \ntechniques, data augmentation strategies, and sensor integration for more precise and \ncomprehensive posture assessment.  \n2. Explore innovativ e feedback mechanisms, such as augmented reality (A visualizations, \nhaptic feedback, or gamification elements, to enhance user engagement and effectiveness \nof posture correction cues).  \n3. Personalized Exercise Recommendations: Expand the range of personalized  exercise \nrecommendations in Physioflex, incorporating diverse exercises targeting specific \nmusculoskeletal issues, mobility challenges, and ergonomic adjustments.  \n4. Integration with Wearable Devices: Explore integration with wearable devices and sensors \nto capture real -time posture data, monitor physical activity levels, and provide \npersonalized feedback and reminders for posture correction throughout the day.  \n5. Data Analytic and Insights: Leverage data analytic and machine learning techniques to \nderive action able insights from user data collected by Physioflex, enabling personalized \ninterventions, trend analysis, and predictive modeling for musculoskeletal health \noutcomes.  \n6. Telehealth and Remote Monitoring: Explore opportunities for integrating Physioflex with \ntelehealth platforms, enabling remote consultations, virtual coaching sessions, and \ncontinuous monitoring of users' progress in posture correction and exercise adherence.  \n7. Accessibility and Inclusivity Features: Enhance Physio flex's accessibility features to cater \nto diverse user needs, including support for different languages, accessibility settings for \nusers with disabilities, and inclusive design principles for a broader user base.  "),
#  Document(metadata={'source': 'samplepdf.pdf', 'page': 47}, page_content='37 \n 8. Clinical Validation and Research Collaborations: Collaborate with health care institutions, \nresearch organizations, and clinical experts to validate the efficacy of Physioflex in clinical \nsettings, conduct longitudinal studies on posture improvement outcomes, and contribute \nto evidence based practices in musculoskeletal health.  \n9. User Engagement and Education Initiatives: Launching user engagement campaigns, \neducational materials, and community initiatives to raise awareness about musculoskeletal \nhealth, promote healthy posture habits, and foster a supportive user community around  \nPhysioflex.  \n10. Scalability and Global Reach: Plan for scalability and global expansion of Physioflex, \nconsidering localization for different regions, compliance with international healthcare \nstandards, and scalability of infrastructure to accommodate growing  user populations.  \n \n  \n \n \n7.3. References  \ni. https://play.google.com/store/apps/details?id=com.physitrack.physiapp HYPERLINK \n"https://play.google.com/store/apps/details?id=com.physitrack.physiapp&pli=1"  \nii. https://www.usa.edu/blog/virtual -physical -therapy/  \niii. https://my.clevelandclinic.org/health/treatments/physical -therapy  \niv. https://www.virtualphysicaltherapists.com/  \n \n \n \n \n ')]

# %%
# Combine all the extracted text into a single string
full_text = "\n".join([doc.page_content for doc in documents])

# Create a RecursiveCharacterTextSplitter instance
chunker = RecursiveCharacterTextSplitter(
    chunk_size=200,
    separators=["\n\n", ".", "!", "?", ",", " ", ""],
    chunk_overlap=20
)

# Split the full text into chunks
chunks = chunker.split_text(full_text)

# Print out the chunks
for i, chunk in enumerate(chunks):
    print(f"Chunk {i+1}:")
    print(chunk)
    print("-" * 40)
# Out:
# Chunk 1:
# University Institute of Information Technology,
# PMAS -Arid Agriculture University
# ----------------------------------------
# Chunk 2:
# ,
# Rawalpindi Pakistan
#
# PhysioFlex -personal Posture Trainer
#
#
# By
#
# Hamza Akram         20-ARID -763
# M Fahad Bashir       20 -ARID -790
# Syeda Moniza           20 -ARID -833
#
#
# Supervisor
# ----------------------------------------
# Chunk 3:
# Supervisor
# Dr
# ----------------------------------------
# Chunk 4:
# . Ruqia Bibi
# Bachelor of Science in Software Engineering  (2020-2024)
#
# II
#
#
# The candidate confirms that the work submitted is their own and appropriate
#  credit has been given where reference
# ----------------------------------------
# Chunk 5:
# where reference has been made to the work of others
# ----------------------------------------
# Chunk 6:
# .
#
# DECLARATION
#
# We hereby declare that this software, neither whole nor as a part has been copied out from any
# source
# ----------------------------------------
# Chunk 7:
# . It is further declared that we have developed this software documentation and
# accompanied report entirely on the basis of our personal efforts
# ----------------------------------------
# Chunk 8:
# . If any part of this project is
# proved to be copied out from any source or found to be reproduction of some other. We will
# stand by the consequences
# ----------------------------------------
# Chunk 9:
# . No Portion of the work presented has been submitted of any
# application for any other degree or qualification of this or any other university or institute of
# learning
# ----------------------------------------
# Chunk 10:
# .
#
# Muhammad Fahad Bashir                Hamza Akram                   Syeda Moniza
#
#                   ---------------------------                               ------------------
# ----------------------------------------
# Chunk 11:
# --------------------
#
#
#
#
# III
#  CERTIFICATE OF APPROVAL
#
# It is to certify that the final year project of BS (SE) “Physioflex -personal Posture Trainer” was
# developed by
# ----------------------------------------
# Chunk 12:
# was
# developed by “Muhammad Fahad Bashir 20-Arid -790”
# ----------------------------------------
# Chunk 13:
# , “Hamza Akram 20-Arid -763” and
# “Syeda Moniza  20-Arid -833” under the supervision of “Dr
# ----------------------------------------
# Chunk 14:
# . Ruqia Bibi” and that in their
# opinion; it is fully adequate, in scope and quality for the degree of Bachelors of Science in
# Software Engineering
# ----------------------------------------
# Chunk 15:
# .
#
#
#
#
# ---------------------------------------
# Supervisor
#
#
#
# ---------------------------------------
# (Mr
# ----------------------------------------
# Chunk 16:
# . Imran Khurram)
# External Examiner
#
#
#
# ---------------------------------------
# DIRECTOR UIIT
#
#
# IV
#  Executive Summary
#
# Our project address musculoskeletal health issues related to
# ----------------------------------------
# Chunk 17:
# issues related to incorrect postures by introducing
# an innovative solution
# ----------------------------------------
# Chunk 18:
# . The existing solutions in the field are criticized for lacking a
# comprehensive approach that integrates real -time posture detection with tailored exercise
# guidance
# ----------------------------------------
# Chunk 19:
# . Many solutions that are excellent requires subscription
# ----------------------------------------
# Chunk 20:
# . To fill this gap, our project
# aims to create a web application that serves  as a vigilant companion
# ----------------------------------------
# Chunk 21:
# , continuously monitoring
# users' posture and providing immediate feedback on deviations from correct alignment
# ----------------------------------------
# Chunk 22:
# .
#
# What distinguishes this project is its emphasis on personalization. The system is designed to
# offer a wide range of exe rcises tailored to each user's specific postural issues
# ----------------------------------------
# Chunk 23:
# . By seamlessly
# integrating real -time posture detection with personalized guidance, users will have a powerful
# tool to rectify their posture habits and foster musculoskeletal health
# ----------------------------------------
# Chunk 24:
# .
#
# The overarching g oal of this project is to enhance the quality of life for individuals by
# addressing the often overlooked aspect of posture
# ----------------------------------------
# Chunk 25:
# . Through real -time monitoring and tailored
# guidance, the web application is poised to empower users to take proactive steps towards
# improving their musculoskeletal health
# ----------------------------------------
# Chunk 26:
# .
#
#
#
#
#
# V
#  Acknowledgement
#
# All praise is to Almighty Allah who bestowed upon us a minute portion of His boundless
# knowledge by virtue of which we were able to accomplish this challenging
# ----------------------------------------
# Chunk 27:
# this challenging task
# ----------------------------------------
# Chunk 28:
# .
# We are greatly indebted to our project supervisor “Dr. Ruqia Bibi” and our Co -Supervisor “Dr.
# Tariq Ali” for personal supervision, advice, valuable guidance and completion of this project
# ----------------------------------------
# Chunk 29:
# .
# We are deeply indebted to him for encouragement and continual help during this work
# ----------------------------------------
# Chunk 30:
# .
# And we ar e also thankful to our parents and family who have been a constant source of
# encouragement for us and brought us the values of honesty & hard work
# ----------------------------------------
# Chunk 31:
# .
#
#
#
#
# Muhammad Fahad Bashir                      Hamza Akram             Syeda Moniza
#
# ---------------------------                        ---------------------------
# ----------------------------------------
# Chunk 32:
# ---------------------------
#
#
#
#
#
#
#
#
# Abbreviations
# VI
#
# SRS  Software Requirement Specification
# PC Personal Computer
# SRE  Software Requirement Engineering
# SDLC  Software
# ----------------------------------------
# Chunk 33:
# SDLC  Software Development Lifecycle
#
#
#
#
#
#
#
#
#
#
#
# Table of Contents
#
# VII
#  Introduction
# ----------------------------------------
# Chunk 34:
# ................................ ................................ ................................ ..............................  1
# 1.1 Brief  ................................ ......................
# ----------------------------------------
# Chunk 35:
# .............................. ................................ ...........................  1
# 1.2 Relevance to Course Modules  ................................ ................................ .....
# ----------------------------------------
# Chunk 36:
# .............. ...................  1
# 1.3 Project Background  ................................ ................................ ................................ .... 2
# 1.4 Literature Review ........
# ----------------------------------------
# Chunk 37:
# ................................ ................................ ................................ ....... 3
# 1.5 Analysisi form Literature Review  ................................ ...................
# ----------------------------------------
# Chunk 38:
# ................................ ..............  3
# 1.6 Methodology and Software  Life Cycle  ................................ ................................ ..... 4
# Problem Definition  ...........
# ----------------------------------------
# Chunk 39:
# ................................ ................................ ................................ ...................  5
# 2.1 Problem Statement  ................................ .....................
# ----------------------------------------
# Chunk 40:
# ............................... ................................ ..... 5
# 2.2 Deliverable and Development Requirements  ................................ ............................  5
# 2
# ----------------------------------------
# Chunk 41:
# ..............  5
# 2.3 Current System ................................ ................................ ................................ ...........  6
# Requirement  Analysis  ........................
# ----------------------------------------
# Chunk 42:
# ............................ ................................ ................................ ..............  8
# 3.1 Functio nal Requirments  ................................ ........................
# ----------------------------------------
# Chunk 43:
# ............................ .............................  8
# 3.2 Non – Functional Requirments  ................................ ................................ ..................  8
# 3.2
# ----------------------------------------
# Chunk 44:
# ............  8
# 3.2.1  Usability …………  ................................ ................................ ................................ . 8
# 3.2.2  Reliability  ................................ ...
# ----------------------------------------
# Chunk 45:
# ................ ................................ ................................ ...............  8
# 3.2.3  Performance  ................................ ................................ ...........
# ----------------------------------------
# Chunk 46:
# ........ ................................ ...........  9
# 3.2.4  Supportability  ................................ ................................ ................................ .........  9
# 3.2
# ----------------------------------------
# Chunk 47:
# .. .........  9
# 3.2.5  Design Constraints  ................................ ................................ ................................ . 9
# 3.2.6  Licensing Requirements ......................
# ----------------------------------------
# Chunk 48:
# .............................. ................................ .........................  9
# 3.3 Use case Model  ................................ ................................ ....................
# ----------------------------------------
# Chunk 49:
# ................................ ........  10
# 3.3.1  Use Case Diagarm ................................ ................................ ................................  10
# 3.3
# ----------------------------------------
# Chunk 50:
# ...........  10
# 3.3.2  Actors Discription  ................................ ................................ ................................  11
# 3.3.3  Use Case Discription ........................
# ----------------------------------------
# Chunk 51:
# ............................ ................................ ............................  11
#
# Design  and Architecture  ................................ ................................ ..........
# ----------------------------------------
# Chunk 52:
# ......... ................................ ........  16
# 4.1 UML Structural Diagrams  ................................ ................................ .......................  16
# 4.1
# ----------------------------------------
# Chunk 53:
# ...........  16
# 4.1.1  Component Diagram  ................................ ................................ ............................  16
# 4.1.2  Deployment Diagram  ..............................
# ----------------------------------------
# Chunk 54:
# ...................... ................................ ...........................  17
# 4.1.3  Class  Diagram  ................................ ................................ ......................
# ----------------------------------------
# Chunk 55:
# .............................. ..... 18
# VIII
#  4.2 UML Structural Diagrams  ................................ ................................ .......................  19
# 4.2
# ----------------------------------------
# Chunk 56:
# ...........  19
# 4.2.1  DFD (Level 0)  Diagram  ................................ ................................ ......................  19
# 4.2.2  DFD (Level 1)  Diagram  ...........................
# ----------------------------------------
# Chunk 57:
# ......................... ................................ .......................  19
# 4.3 UML Interaction  Diagrams  ................................ ................................ ...............
# ----------------------------------------
# Chunk 58:
# .... ......................  20
# 4.3.1  Sequence Diagrams  ................................ ................................ ..............................  20
#
# Implementation  .....................
# ----------------------------------------
# Chunk 59:
# ............................... ................................ ................................ ......................  21
# 5.1 Component Diagram  ................................ ..................
# ----------------------------------------
# Chunk 60:
# . ................................ ...............................  21
# 5.2 Network and protocol choice  ................................ ................................ ...................  23
# 5
# ----------------------------------------
# Chunk 61:
# .............  23
# 5.3 User Interface  ................................ ................................ ................................ ...........  24
#
# Testing and Evaluation  ...................
# ----------------------------------------
# Chunk 62:
# ................................ ................................ ................................ ..........  28
# 6.1 Verification  ................................ ................................ .
# ----------------------------------------
# Chunk 63:
# .................. ................................ ..............  28
# 6.1.1  Functional Testing  ................................ ................................ ..............................
# ----------------------------------------
# Chunk 64:
# .....................  28
# 6.1.2  Static Testing  ................................ ................................ ................................ ....... 28
# 6.2 Validation  .......................
# ----------------------------------------
# Chunk 65:
# ............................. ................................ ................................ .................  28
# 6.3 Usability Testing  ................................ .........................
# ----------------------------------------
# Chunk 66:
# ........................... ................................ ...... 28
# 6.4 Unit Testing  ................................ ................................ ................................ ...........
# ----------------------------------------
# Chunk 67:
# ........ .............  28
# 6.5 Test Cases for Managing Login Functionality  ................................ ..............................  29
# 6.6        Integration Testing .......................
# ----------------------------------------
# Chunk 68:
# ............................. ................................ ................................ .. 31
# 6.7        System Testing  ................................ ................................ ....
# ----------------------------------------
# Chunk 69:
# ............... ................................ ........  31
# 6.8        Acceptance Testing  ................................ ................................ ................................ . 31
# 6
# ----------------------------------------
# Chunk 70:
# ............ . 31
# 6.9        Stress Testing ................................ ................................ ................................ ...........  31
# 6
# ----------------------------------------
# Chunk 71:
# . ...........  31
# 6.10      Hardware Configuration for Tetsing  ................................ ................................ ...... 32
# 6.11      Evaluation  ................................ ...
# ----------------------------------------
# Chunk 72:
# ................ ................................ ................................ ................  32
# 6.12      Deployment  ................................ ................................ .......
# ----------------------------------------
# Chunk 73:
# ............ ................................ .............  33
# 6.13      Maintenance  ................................ ................................ ................................ .............
# ----------------------------------------
# Chunk 74:
# ...... ..............  34
# Conclusion and Future work  ................................ ................................ ...............................  36
# 7.1 Conclusion  ..........................
# ----------------------------------------
# Chunk 75:
# .......................... ................................ ................................ ...............  36
# 7.2 Future Work  ................................ ................................ ...
# ----------------------------------------
# Chunk 76:
# ................ ................................ .............  36
# IX
#  7.3 Refrence  ................................ ................................ ................................ .............
# ----------------------------------------
# Chunk 77:
# ...... ...................  36
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# List of Figures
#
# Fig 1.1 Block Diagram  ................................ ................................ ...............................
# ----------------------------------------
# Chunk 78:
# ..................... ...............  7
# X
#  Fig 3 .1 Use Case Diagram  ................................ ................................ ................................ ....... 10
# Fig 4
# ----------------------------------------
# Chunk 79:
# .. ....... 10
# Fig 4.1 Component Diagram ................................ ................................ ................................ .... 16
# Fig 4.2 Deployment Diagram  .......................
# ----------------------------------------
# Chunk 80:
# ............................. ................................ ................................ .. 17
# Fig 4.3 Class Diagram ................................ ................................ .........
# ----------------------------------------
# Chunk 81:
# .......... ................................ ..............  18
# Fig 4.4 DFD (Level 0 ) Diagram  ................................ ................................ ............................
# ----------------------------------------
# Chunk 82:
# .....................  19
# Fig 4.5 DFD (Level 1)  Diagram  ................................ ................................ .............................  19
# Fig 4.6 Sequence  Diagram  .............
# ----------------------------------------
# Chunk 83:
# ................................ ................................ ................................ ...... 20
# Fig 5.1 Home Page  ................................ ................................ .....
# ----------------------------------------
# Chunk 84:
# .............. ................................ ...................  26
# Fig 5.2  Main Sections  ................................ ................................ ................................ ....
# ----------------------------------------
# Chunk 85:
# ............... ..............  26
# Fig 5.3 Live Pose  ................................ ................................ ................................ .....................  27
# Fig 5
# ----------------------------------------
# Chunk 86:
# .........  27
# Fig 5.4 PhysioFlex Assitant  ................................ ................................ ................................ ....
# ----------------------------------------
# Chunk 87:
# ............... ..... 27
#
#
#
#
#
#
#
#
#
#
#
#
#
# XI
#
#   List of Tables
# Table  3.1 Create Account  ................................ ................................ .............................
# ----------------------------------------
# Chunk 88:
# ....................... ....... 11
# Table  3.2 Log in  ................................ ................................ ................................ ......................  12
# Table  3
# ----------------------------------------
# Chunk 89:
# ......  12
# Table  3.3 Browse Exercise and Training  ................................ ................................ ................  12
# Table  3.4 Search Exercise  ...............................
# ----------------------------------------
# Chunk 90:
# ..................... ................................ ................................ ........  13
# Table  3.5 View Exercise Details  ................................ ...............................
# ----------------------------------------
# Chunk 91:
# ..................... .............................  13
# Table  3.6 Start Training  ................................ ................................ ................................ ..........
# ----------------------------------------
# Chunk 92:
# ......... ...........  14
# Table  3.7 Configure Training Session  ................................ ................................ ....................  14
# Table  3.8 Evaluate Session  .............
# ----------------------------------------
# Chunk 93:
# ................................ ................................ ................................ ...... 15
# Table  3.9 Log Out  ................................ ................................ ....
# ----------------------------------------
# Chunk 94:
# ............... ................................ ..................
# ----------------------------------------
# Chunk 95:
# ...................  15
#
#
# 1
#  Chapter 1: Introduction
# Musculoskeletal health issues, often stemming from incorrect postures, are pervasive and can
# lead to discomfort and various health problems
# ----------------------------------------
# Chunk 96:
# . This Final Year Project (FYP) endeavors to
# address this issue by introducing an innovative solution that combines real -time feedback and
# personalized exercise recommendations for postural
# ----------------------------------------
# Chunk 97:
# for postural correction
# ----------------------------------------
# Chunk 98:
# .
#
# The existing solutions in the field lack a comprehensive approach that integrates real -time
# posture detection with tailored exercise guidance
# ----------------------------------------
# Chunk 99:
# . Our project aims to bridge this gap by
# creating a web application that functions as a vigilant companion
# ----------------------------------------
# Chunk 100:
# , continuously monitoring a
# user's posture and offering immediate feedback on any deviations from correct alignment
# ----------------------------------------
# Chunk 101:
# .
#
# What sets this project apart is its emphasis on personalization. The system is designed to
# provide individualized exercise recommendations that cater to each user's unique postural
# issues
# ----------------------------------------
# Chunk 102:
# . By seamlessly integratin g real -time posture detection with personalized guidance, users
# gain a powerful tool to rectify their posture habits and promote musculoskeletal health
# ----------------------------------------
# Chunk 103:
# .
#
# The ultimate goal of this project is to enhance the quality of life for individuals by addressing
# an often overlooked aspect of their well -being posture
# ----------------------------------------
# Chunk 104:
# . Through real -time monitoring and
# tailored guidance, this web application will empower users to take proactive steps towards
# improving their musculoskeletal health.
# 1.1
# ----------------------------------------
# Chunk 105:
# .
# 1.1.  Brief
# Our aim is to develop a web appli cation that focuses on musculoskeletal health
# ----------------------------------------
# Chunk 106:
# . It aims to
# address posture -related issues by providing real -time posture feedback and personalized
# exercise recommendations to improve and maintain good posture
# ----------------------------------------
# Chunk 107:
# . This will be implemented
# using technologies lik e TensorFlow.js.
# 1.2
# ----------------------------------------
# Chunk 108:
# .  Relevance to Course Modules
# Our project is directly aligned with fundamental courses studied during our degree program
# ----------------------------------------
# Chunk 109:
# ,
# providing the essential knowledge and skills crucial for the successful development of our
# posture correction web appl ication
# ----------------------------------------
# Chunk 110:
# .
#
# 1.2
# ----------------------------------------
# Chunk 111:
# .1 Programming Fundamentals and Object -Oriented Programming:
# These courses have laid a robust foundation
# ----------------------------------------
# Chunk 112:
# , particularly in the realm of back -end development
# where JavaScript serves as the primary language
# ----------------------------------------
# Chunk 113:
# . The concepts acquired in programming
# fundamentals and object -oriented programming are fundamental to building the core
# functionality of our application.
#
#
# 2
#
# 1.2
# ----------------------------------------
# Chunk 114:
# .
#
#
# 2
#
# 1.2.2 Data Structures & Algorithms:
# Our proficiency in data structures and algorithms is pivotal in crafting efficient posture
# correction  algorithms
# ----------------------------------------
# Chunk 115:
# . It empowers us to select appropriate data types and implement optimized
# solutions, ensuring the accuracy and effectiveness of our application.
#
# 1.2
# ----------------------------------------
# Chunk 116:
# .3 Software Requirements Engineering:
# Software Requirements Engineering (SRE) has been a corners tone in our educational journey
# ----------------------------------------
# Chunk 117:
# ,
# imparting insights and techniques crucial for the conceptualization and construction of projects
# ----------------------------------------
# Chunk 118:
# .
# The knowledge gained is invaluable in the initial phase of our project, where we gather
# requirements, ensuring alignment with  the real pain points of our target users.
#
# 1.2
# ----------------------------------------
# Chunk 119:
# .
#
# 1.2.4 Database:
# Databases, as the backbone of any web application or software, are addressed through our
# knowledge gained in this course
# ----------------------------------------
# Chunk 120:
# . It equips us to design and implement a modern, fast, and
# reliable database , drawing upon fundamental concepts to ensure seamless data management
# within our application.
#
# 1.2
# ----------------------------------------
# Chunk 121:
# .5 Software Quality Engineering:
# Our understanding of software quality engineering, encompassing testing methodologies and
# quality assurance
# ----------------------------------------
# Chunk 122:
# , is instrumental  in maintaining high standards of quality for our application
# ----------------------------------------
# Chunk 123:
# .
# It guides us in conducting various types of testing to deliver a reliable and high -quality product
# to our users
# ----------------------------------------
# Chunk 124:
# .
#
# In summary, the knowledge and skills acquired in these courses directly contrib ute to the
# development and success of our posture correction web application
# ----------------------------------------
# Chunk 125:
# . They provide the necessary
# tools and expertise to tackle the challenges associated with the project, ensuring that we deliver
# a robust and high -quality solution.
# 1.3
# ----------------------------------------
# Chunk 126:
# .
# 1.3.  Project Backgro und
# The inspiration for this project stems from a pressing need within the field of musculoskeletal
# health
# ----------------------------------------
# Chunk 127:
# . Patients undergoing physiotherapy often face the challenge of maintaining proper
# posture, which is essential for their recovery and overall well -being
# ----------------------------------------
# Chunk 128:
# . This need is particularly
# pronounced in cases where physiotherapists cannot be present at all times to provide real -time
# guidance and supervision
# ----------------------------------------
# Chunk 129:
# .
#
# Furthermore, engaging a personal trainer or assistant for regular posture correction exercises
# can be b oth expensive and time -consuming
# ----------------------------------------
# Chunk 130:
# . Many individuals with musculoskeletal issues find
# it difficult to access expert guidance consistently, limiting the effectiveness of their exercises
# ----------------------------------------
# Chunk 131:
# .
#
# Recognizing these challenges, our project was conceived to bridge this  gap in patient care by
# developing a web application .We aim to provide an accessible and cost -effective solution
# ----------------------------------------
# Chunk 132:
# .
# This application serves as a virtual assistant, offering continuous guidance and feedback to
# 3
#  users
# ----------------------------------------
# Chunk 133:
# , thereby helping them to rectify their pos ture issues and improve their musculoskeletal
# health, all while mitigating the difficulties and time constraints often associated with these
# endeavors
# ----------------------------------------
# Chunk 134:
# .
# 1.4.  Literature Review
#
# 1.4
# ----------------------------------------
# Chunk 135:
# .4.1 Research:
# Research on "Posture and Musculoskeletal Implications for Students Using Mobile Phones" is
# highly relevant in the context of the current trend of remote learning
# ----------------------------------------
# Chunk 136:
# . This research can shed
# light on the impact of extended mobile phone use on posture and musculoskeletal health, which
# aligns with the concerns our project aims t o address.
# 1.4.2 Products:
# 1
# ----------------------------------------
# Chunk 137:
# .4.2 Products:
# 1. "Wearable Posture Correction Devices" such as the Upright GO 2 Premium are examples of
# products that are gaining popularity
# ----------------------------------------
# Chunk 138:
# . These devices provide real -time feedback and reminders
# to users, helping them maintain proper postur e
# ----------------------------------------
# Chunk 139:
# . Mentioning specific products like this
# demonstrates the practical applications of posture correction technology.
# 2
# ----------------------------------------
# Chunk 140:
# .
# 2. "User -centric Applications" that focus on customization and personalized exercise plans are
# in line with the user -centered approach we ai m to adopt in our project
# ----------------------------------------
# Chunk 141:
# . This trend emphasizes
# the importance of engaging users actively in their posture correction efforts.
# 3
# ----------------------------------------
# Chunk 142:
# .
# 3. The idea of "Building a Poor Body Posture Detection & Alert System" aligns with the core
# objective of our project, which is t o develop a real -time posture monitoring and correction
# system
# ----------------------------------------
# Chunk 143:
# . This could serve as a relevant research direction and product concept for your literature
# review.
# 1.5
# ----------------------------------------
# Chunk 144:
# .5. Analysis from Literature Review
# After reading the above literature reviews and viewing t he products come to conclusion that
# there is need for a solutions that is friendly and have real updates
# ----------------------------------------
# Chunk 145:
# . Many products and services
# like Phio need subscription and difficult to get access. We have to get program code. Apps like
# Total Rehab only provides c linical video demo and required subscription
# ----------------------------------------
# Chunk 146:
# .
# 1.6. Methodology and Software Lifecycle for This Project
# For our project, we have chosen the agile methodology as the foundation for our software
# development process
# ----------------------------------------
# Chunk 147:
# . Agile is a dynamic and iterative appr oach that promotes flexibility and
# adaptability, making it particularly suitable for our project's nature
# ----------------------------------------
# Chunk 148:
# . Here's how we plan to
# implement Agile for our software development life cycle (SDLC):
# 4
#  Agile Methodology:
# 1
# ----------------------------------------
# Chunk 149:
# . Iterative and Incremental Development: We will break the project into small, manageable
# increments or sprints. Each sprint will focus on specific features or functionalities.
# 2
# ----------------------------------------
# Chunk 150:
# .
# 2. Collaborative Teamwork : Agile encourages close collaboration among team members,
# including developers, designers, and d omain experts
# ----------------------------------------
# Chunk 151:
# . We will work closely with
# physiotherapists and potential users to ensure that the application meets their needs effectively.
# 3
# ----------------------------------------
# Chunk 152:
# .
# 3. Customer -Centric Approach:  Agile places a strong emphasis on customer feedback
# ----------------------------------------
# Chunk 153:
# . We
# will regularly demonstrate the  application to users, gather their feedback, and use it to refine
# the features and functionalities
# ----------------------------------------
# Chunk 154:
# , ensuring that the end product is aligned with user expectations
# ----------------------------------------
# Chunk 155:
# .
# 4. Flexibility and Adaptability: Agile allows us to adapt to changing requirements or insi ghts
# throughout the project
# ----------------------------------------
# Chunk 156:
# . As we delve deeper into the development process, we can adjust our
# priorities and approaches as needed to achieve the best possible outcomes.
# 5
# ----------------------------------------
# Chunk 157:
# .
# 5. Continuous Testing and Quality Assurance: Quality is paramount, and Agile integrat es
# testing into every phase of development
# ----------------------------------------
# Chunk 158:
# . This ensures that the application remains stable and
# reliable at all times
# ----------------------------------------
# Chunk 159:
# .
#
# By adopting the agile methodology, we intend to create a responsive and user -centric posture
# correction web application
# ----------------------------------------
# Chunk 160:
# . The Agile prin ciples of collaboration, flexibility
# ----------------------------------------
# Chunk 161:
# , and continuous
# improvement are vital in addressing the evolving needs of physiotherapist patients and
# providing a solution that is not only effective but also adaptable to changing requirements
# ----------------------------------------
# Chunk 162:
# requirements and
# user expectations
# ----------------------------------------
# Chunk 163:
# .
# 1.6.1. Rationale behind Selected Methodology
# We selected the Agile methodology and a corresponding software development life cycle
# (SDLC) due to their adaptability and user -centric approach
# ----------------------------------------
# Chunk 164:
# . Agile's flexibility allows us to
# respond to changing requirements and gather continuous user feedback
# ----------------------------------------
# Chunk 165:
# . The chosen SDLC
# aligns with Agile's iterative development, ensuring incremental progress and regular testing to
# maintain high -quality standards
# ----------------------------------------
# Chunk 166:
# . Both methodologies are well -suited for our posture correction
# project, ena bling us to create an effective, user -driven solution that addresses evolving needs
# in musculoskeletal health
# ----------------------------------------
# Chunk 167:
# .
#
#
#
#
#
#  Chapter 2: Problem Definition
# 5
#  2.1
# ----------------------------------------
# Chunk 168:
# .1. Problem Statement
# In the field of musculoskeletal health, there exists a significant challenge related to maintaining
# correct postures, especially for patients undergoing physiotherapy
# ----------------------------------------
# Chunk 169:
# . Incorrect postures can
# hinder the healing process, lead to discomfort, and contribute to long -term health issues
# ----------------------------------------
# Chunk 170:
# . The
# current solutions often lack the integration of real -time posture detection and personalized
# exercise guidance
# ----------------------------------------
# Chunk 171:
# , making it difficult for individuals to receive immediate feedback and
# tailored recommendations to rectify their posture habits
# ----------------------------------------
# Chunk 172:
# . This deficiency in the current
# approach creates a pressing need for a s olution that offers real -time posture monitoring and
# personalized exercise recommendations
# ----------------------------------------
# Chunk 173:
# , addressing the pain points of physiotherapist patients
# and others seeking to improve their posture
# ----------------------------------------
# Chunk 174:
# .
# 2.2. Deliverables and Development Requirements
# 2.2.1 Deliverable s:
#
# 1
# ----------------------------------------
# Chunk 175:
# .  Posture Correction Web Application: The primary deliverable is a fully functional web
# application that provides real -time posture monitoring and personalized exercise
# recommendations
# ----------------------------------------
# Chunk 176:
# . Users should be able to access and use this application seamlessly.
#
# 2
# ----------------------------------------
# Chunk 177:
# .
#
# 2.  User Documentation : Clear and comprehensive user documentation, including guides and
# tutorials on how to use the application effectively.
#
# 3
# ----------------------------------------
# Chunk 178:
# .
#
# 3.  System Documentation : In-depth system documentation detailing the application's
# architecture, codebase, and any APIs used.
#
# 4
# ----------------------------------------
# Chunk 179:
# .
#
# 4. Testing and Quality Assurance Reports : Documentation of rigorous testing and quality
# assurance efforts, ensuring the application's reliability and accuracy.
#
#
# 5
# ----------------------------------------
# Chunk 180:
# .
#
#
# 5. Maintenance and Support Plan: A plan outlining ongoing maintenance, updates, and u ser
# support to ensure the application remains effective and up -to-date.
#
#
# 2.2
# ----------------------------------------
# Chunk 181:
# .
#
#
# 2.2.2 Development Requirements:
#
# 1. Programming Languages : Proficiency in web development languages such as JavaScript,
# HTML, and CSS is essential
# ----------------------------------------
# Chunk 182:
# . Additional skills in Python or oth er languages may be required
# for backend development.
#
# 2
# ----------------------------------------
# Chunk 183:
# .
#
# 2. Frontend Development: Expertise in frontend frameworks like React for creating the user
# interface and ensuring a user -friendly experience.
#
# 6
#  3
# ----------------------------------------
# Chunk 184:
# .
#
# 6
#  3. Backend Development:  Competence in backend technologies  like Node.js, Express, and
# databases (e.g., MongoDB) for handling data and real -time monitoring.
#
# 4
# ----------------------------------------
# Chunk 185:
# .
#
# 4. Machine Learning and AI:  Knowledge of machine learning algorithms for posture
# detection and AI for personalized exercise recommendations.
#
# 5
# ----------------------------------------
# Chunk 186:
# .
#
# 5. Database Management:  Skills in designing, implementing, and maintaining databases to
# store user data and posture information.
#
# 6
# ----------------------------------------
# Chunk 187:
# .
#
# 6. Security Measures : Implementation of robust security measures to protect user data and
# ensure compliance with privacy regulations.
#
# 7
# ----------------------------------------
# Chunk 188:
# .
#
# 7. User Experience (UX) Design : Incorporation of effective UX design principles to create an
# intuitive and engaging interface.
#
# 8
# ----------------------------------------
# Chunk 189:
# .
#
# 8. Testing and Quality Assurance : Rigorous testing methodologies to ensure the application's
# reliability, accuracy, and overall qua lity
# ----------------------------------------
# Chunk 190:
# .
#
# These Deliverables and development requirements are essential for the successful
# implementation of the posture correction web application, aligning with the project's goals and
# objectives.
# 2
# ----------------------------------------
# Chunk 191:
# .
# 2.3
# ----------------------------------------
# Chunk 192:
# . Current System
# PhysiApp is the companion app to Phys t rack
# ----------------------------------------
# Chunk 193:
# , the platform that lets healthcare providers such
# as physiotherapists create and prescribe clinical exercise programs and conduct Telehealth
# consultations
# ----------------------------------------
# Chunk 194:
# .
# When you use PhysiApp, your healthcare provider can accurately monitor your progress and
# feedba ck, allowing them to provide better support based on real data
# ----------------------------------------
# Chunk 195:
# . Clinical studies confirm
# that apps like ours can help improve outcomes for patients.
#
# 7
#
#
# Figure 1.1: PhysiApp
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 8
#  Chapter 3: Requirement Analysis
# 3.1
# ----------------------------------------
# Chunk 196:
# .1. Functional Requirements
# Following are the functional requirements for our project
# ----------------------------------------
# Chunk 197:
# .
#
# User Authentication and Profile Management:
# The system shall provide secure user authentication, allowing users to create accounts and log
# in securely
# ----------------------------------------
# Chunk 198:
# . Users should have th e capability to create and manage personalized profiles,
# including essential details and preferences
# ----------------------------------------
# Chunk 199:
# .
#
# Real -time Posture Monitoring:
# The application shall employ real -time posture detection mechanisms, utilizing camera inputs
# to continuously monitor the us er's posture
# ----------------------------------------
# Chunk 200:
# . The system should provide immediate feedback to
# the user regarding deviations from correct posture alignment
# ----------------------------------------
# Chunk 201:
# .
#
# Personalized Exercise Recommendations:
# The application shall offer tailored exercise recommendations based on the user's unique
# postural issues
# ----------------------------------------
# Chunk 202:
# . These exercise recommendations should be adaptive, evolving as the user
# progresses in their posture correction journey
# ----------------------------------------
# Chunk 203:
# .
#
# Data Storage and Management:
# The application shall securely store user data, including posture history and exercise
# preferences
# ----------------------------------------
# Chunk 204:
# . Data management should adhere to privacy and security standards, with robust
# backup and recovery mechanisms in place
# ----------------------------------------
# Chunk 205:
# .
#
# Exercise Selection and Customization:
# The system shall provide users with a diverse catalog of posture correction exercises,
# categorizing them based on specific purpose
# ----------------------------------------
# Chunk 206:
# .Users should have the capability to select
# exercises based on personal preferences, allowing for a customizable and engaging workout
# routine
# ----------------------------------------
# Chunk 207:
# .
# The application shall offer detailed descriptions and visual guides for each exercise, aiding
# users in understanding and performing them accurately.
#
# 3.2. Non -Functional Requirements
#   3.2
# ----------------------------------------
# Chunk 208:
# .2.1. Usability:
# The user interface shall adhere to established design principles, ensuring an intuitive and
# visually appealing experience .
#
#  3.2.2
# ----------------------------------------
# Chunk 209:
# .
#
#  3.2.2. Reliability:
# The system shall incorporate effective error handling mechanisms to provide users with clear
# and informative error messages.
# 9
#
# 3.2.3
# ----------------------------------------
# Chunk 210:
# .
# 9
#
# 3.2.3. Performance:
# The application shall respond to user inputs within 3 seconds to ensure a seamless and
# responsive user experience.
# 3.2.4
# ----------------------------------------
# Chunk 211:
# .
# 3.2.4.  Supportability:
# It should be designed with robust Supportability features to ensure ease of maintenance,
# updates, and troubleshooting
# ----------------------------------------
# Chunk 212:
# . This includes:
# Modularity: The system should be modular, allowing for straightforward  updates and
# modifications to individual components without affecting the entire application
# ----------------------------------------
# Chunk 213:
# .
# Documentation: Comprehensive documentation for system architecture, code base, and APIs
# should be provided to facilitate efficient troubleshooting, updates, and f uture development
# ----------------------------------------
# Chunk 214:
# .
# User Support: A user -friendly support system, including FAQs, user guides, and a responsive
# help desk, should be in place to assist users with any queries or issues.
# 3.2.5
# ----------------------------------------
# Chunk 215:
# .
# 3.2.5. Design Constraints
# Browser Compatibility: The application should  be compatible with major web browsers such
# as Chrome, Firefox, Safari, and Edge to ensure a consistent user experience
# ----------------------------------------
# Chunk 216:
# .
# Network Requirements: The application should perform optimally under standard internet
# connectivity conditions, accommodating users wit h varying network speeds.
#
# 3.2.6
# ----------------------------------------
# Chunk 217:
# . Licensing Requirements
# The posture correction web application will adhere to the following licensing requirements:
# Open Source Licensing: The application will be released under an open -source
# ----------------------------------------
# Chunk 218:
# an open -source license
# ----------------------------------------
# Chunk 219:
# ,
# providing users with  the freedom to view, modify, and distribute the source code
# ----------------------------------------
# Chunk 220:
# .
# Commercial Use: Users will be permitted to use the application for both personal and
# commercial purposes, encouraging widespread adoption
# ----------------------------------------
# Chunk 221:
# .
# Compatibility: The selected license should be compatibl e with other open -source licenses to
# promote collaboration within the development community.
# 10
#  3.3
# ----------------------------------------
# Chunk 222:
# .
# 10
#  3.3. Use Cases Model
#
#
#
#                                                         Fig 3.1: Use Case Diagram
#
#
# 11
#  3.4
# ----------------------------------------
# Chunk 223:
# .4. Actors  Description:
#  Primary Actors:
# The primary actor is the end -user who interacts directly with the posture correction web
# application
# ----------------------------------------
# Chunk 224:
# . Users engage in activities such as logging in, monitoring their posture in real -time,
# receiving feedback, selecting exercises, and viewin g progress
# ----------------------------------------
# Chunk 225:
# . The user is the focal point of the
# system and directly benefits f rom the application's features
# ----------------------------------------
# Chunk 226:
# .
#  Secondary Actor:
# An administrator may be considered as a secondary actor responsible for managing system
# settings, user accounts
# ----------------------------------------
# Chunk 227:
# , user accounts, and ensuring the  overall functionality and security of the posture
# correction web application
# ----------------------------------------
# Chunk 228:
# .
#
# 3.5. Use cases Description
# Use cases are a widely used and highly regarded format for capturing requirements.
#
# Use Case ID:   UC-1.2
# ----------------------------------------
# Chunk 229:
# .2.1
# Use Case Name:  Create Account
# Actors:  Patient
# Description:  This use case involves the process of registering and creating a user
# account within the system
# ----------------------------------------
# Chunk 230:
# .
#
# Trigger:  The user wants to create a new account.
#
#     Preconditions:  The user is not logged in and does not have an existing account
# ----------------------------------------
# Chunk 231:
# .
# Post conditions : The user's account is successfully created.
# Normal Flow:  The user accesses the registration page
# ----------------------------------------
# Chunk 232:
# .
# The user provides the necessary information, including username,
# email, and password.
# The system validates the information. The  system creates a new user
# account
# ----------------------------------------
# Chunk 233:
# .
# The system sends a confirmation or welcome email to the user
# ----------------------------------------
# Chunk 234:
# .
#
# Exceptions:  If the provided information is incomplete or invalid, the system
# displays an error message and does not create the account
# ...
# ,
# user feedback, and performance metrics to guide decision -making processes
# ----------------------------------------
# Chunk 431:
# . This involves
# analyzing qualitative and quantitative data to make informed decisions about feature
# enhan cements, bug fixes, performance optimizations, and usability improvements.
#
# 5
# ----------------------------------------
# Chunk 432:
# . Iterative Refinement Process:
# Evaluation drives an iterative refinement process in Physioflex, where identified issues are
# addressed, enhancements are implemented
# ----------------------------------------
# Chunk 433:
# , and new features are added based on user needs
# and feedback
# ----------------------------------------
# Chunk 434:
# . This iterative approach ensures continuous improvement and evolution of
# Physioflex to meet user expectations and industry standards.
# 6
# ----------------------------------------
# Chunk 435:
# .
# 6. User Feedback Incorporation:
# 33
#  It includes incorporating user feedbac k gathered during usability testing, acceptance testing,
# and beta testing phases
# ----------------------------------------
# Chunk 436:
# . User feedback is valuable in understanding user preferences, pain
# points, and feature requests, guiding enhancements and updates to align Physioflex with user
# expectations an d preferences.
# 6.12
# ----------------------------------------
# Chunk 437:
# .
# 6.12. Deployment
# 1
# ----------------------------------------
# Chunk 438:
# . Production Environment Setup:
# Deployment of Physioflex involves setting up the production environment, including
# configuring servers, databases, network infrastructure, and security measures
# ----------------------------------------
# Chunk 439:
# . This ensures a
# robust and sec ure environment for hosting Physioflex and managing user data securely.
#
# 2
# ----------------------------------------
# Chunk 440:
# . Quality Assurance Checks:
# Before deployment, quality assurance checks are conducted to ensure that Physioflex meets all
# quality standards, including functionality, performance, sec urity
# ----------------------------------------
# Chunk 441:
# , sec urity, and usability
# ----------------------------------------
# Chunk 442:
# . This involves
# final testing and validation to confirm that all identified issues have been addressed, and the
# application is ready for production release.
#
# 3
# ----------------------------------------
# Chunk 443:
# .
#
# 3. Roll-out Strategy:
# A roll out strategy is defined for deploying Physioflex to users, healthcare providers, and
# stakeholders
# ----------------------------------------
# Chunk 444:
# . This may include phased roll out to specific user groups, geographical regions,
# or targeted audiences to manage deployment risks, gather feedback
# ----------------------------------------
# Chunk 445:
# , gather feedback, and ensure a smooth
# transition to the live environment
# ----------------------------------------
# Chunk 446:
# .
#
# 4
# ----------------------------------------
# Chunk 447:
# . Version Control and Release Management:
# Version control and release management processes are implemented to track changes, manage
# code versions
# ----------------------------------------
# Chunk 448:
# , and ensure controlled deployment of updates and new features
# ----------------------------------------
# Chunk 449:
# . This includes
# documenting release notes, manag ing dependencies, and coordinating release schedules to
# minimize disruptions and ensure compatibility.
#
# 5
# ----------------------------------------
# Chunk 450:
# .
#
# 5. Post -Deployment Monitoring :
# After deployment, ongoing monitoring and performance evaluation are conducted to assess
# Physio flex's performance in the production environment
# ----------------------------------------
# Chunk 451:
# . This involves monitoring system
# health, user activity, performance metrics, error logs, and security incidents to detect and
# address any issues promptly.
#
# 6
# ----------------------------------------
# Chunk 452:
# . User Training and Support:
# User training and support resources are provide d to users, healthcare providers, and
# administrators to familiarize them with Physio flex's features, functionalities
# ----------------------------------------
# Chunk 453:
# , functionalities, and best
# practices
# ----------------------------------------
# Chunk 454:
# . This includes user guides, tutorials, help documentation, and access to technical
# support channels for assistance and  troubleshooting.
#
#
# 7
# ----------------------------------------
# Chunk 455:
# .
#
#
# 7. Continuous Improvement and Updates:
# 34
#  Deployment of Physioflex is followed by a commitment to continuous improvement and
# updates
# ----------------------------------------
# Chunk 456:
# . This involves gathering user feedback, monitoring application performance,
# identifying areas for enhancem ent, and releasing updates, patches, and new features to enhance
# user experience
# ----------------------------------------
# Chunk 457:
# , address emerging needs, and stay competitive in the market
# ----------------------------------------
# Chunk 458:
# .
#
# 8
# ----------------------------------------
# Chunk 459:
# . Compliance and Data Security:
# Deployment includes ensuring compliance with regulatory requirements, data protection laws,
# and industry standards related to healthcare data privacy and security
# ----------------------------------------
# Chunk 460:
# . This includes
# implementing data encryption, access controls, audit trails, and security protocols to protect
# user data and maintain regulatory compliance.
# 6.13. Mainte nance
# 1
# ----------------------------------------
# Chunk 461:
# . Mainte nance
# 1. Bug Fixes and Issue Resolution:
# Continuous monitoring and addressing of bugs, errors, and issues reported by users or
# identified through monitoring systems
# ----------------------------------------
# Chunk 462:
# . This includes prompt investigation, debugging, and
# deployment of fixes to maintain applica tion functionality and user experience.
#
# 2
# ----------------------------------------
# Chunk 463:
# .
#
# 2. Performance Monitoring and Optimization:
# Ongoing monitoring of application performance metrics such as response times, resource
# utilization, and system stability
# ----------------------------------------
# Chunk 464:
# . Optimization efforts focus on improving performan ce,
# scalability, and efficiency through code optimizations, database tuning, and infrastructure
# upgrades as needed.
#
# 3
# ----------------------------------------
# Chunk 465:
# .
#
# 3. Security Updates and Vulnerability Management :
# Regular security assessments, vulnerability scans, and updates to protect against cyber s ecurity
# threats
# ----------------------------------------
# Chunk 466:
# . This includes applying security patches, implementing security best practices, securing
# data transmission, and ensuring compliance with data protection regulations.
#
# 4
# ----------------------------------------
# Chunk 467:
# .
#
# 4. Data Management and Backup Strategies:
# Implementing data management pr actices to ensure data integrity, availability, and
# confidentiality
# ----------------------------------------
# Chunk 468:
# . This includes regular data backups, disaster recovery planning, data retention
# policies, and data encryption to safeguard sensitive user information.
#
# 5
# ----------------------------------------
# Chunk 469:
# .
#
# 5. User Support and Training:
# Providing ongoing user support through help desk services, technical assistance, and
# troubleshooting guidance
# ----------------------------------------
# Chunk 470:
# . User training materials, documentation, and resources are updated
# and maintained to help users navigate the application effectively and maximize its benefits.
#
#
#
#
# 6
# ----------------------------------------
# Chunk 471:
# .
#
#
#
#
# 6. Version Control and Release Management:
# 35
#  Managing version control for application updates, patches, and new releases
# ----------------------------------------
# Chunk 472:
# . This includes
# maintaining a release schedule, documenting release notes, managing dependencies, and
# ensuring smooth de ployment of updates to minimize disruptions.
#
# 7
# ----------------------------------------
# Chunk 473:
# .
#
# 7. Feedback Collection and Analysis:
# Continuously gathering user feedback, feature requests, and suggestions for improvement
# ----------------------------------------
# Chunk 474:
# .
# Feedback analysis informs prioritization of enhancements, usability improvements, an d new
# feature development to align the application with user needs and expectations.
#
# 8
# ----------------------------------------
# Chunk 475:
# .
#
# 8. Performance Testing and Monitoring:
# Conducting periodic performance testing and monitoring to assess application scalability,
# reliability, and responsiveness
# ----------------------------------------
# Chunk 476:
# . This inc ludes load testing, stress testing, and performance
# tuning to maintain optimal performance under varying usage conditions.
#
# 9
# ----------------------------------------
# Chunk 477:
# .
#
# 9. User Engagement and Community Building:
# Engaging with users, stakeholders, and the healthcare community to foster a collaborative
# environment
# ----------------------------------------
# Chunk 478:
# . This includes participation in user forums, community discussions, and feedback
# sessions to gather insights, build relationships, and promote user engagement with Physioflex.
#
# 10
# ----------------------------------------
# Chunk 479:
# .
#
# 10. Technology Upgrades and Innovation:
# Keeping abreast of technol ogical advancements, frameworks, and tools relevant to
# musculoskeletal health and digital healthcare
# ----------------------------------------
# Chunk 480:
# . This includes evaluating new technologies,
# incorporating innovative features, and leveraging emerging trends to enhance Physio flex's
# capabilities and use r experience
# ----------------------------------------
# Chunk 481:
# .
#
#
#
# 36
#  Chapter 7: Conclusion and Future Work
# 7.1. Conclusion
# Physioflex represents a groundbreaking advancement in addressing musculoskeletal health
# through technology -driven solutions
# ----------------------------------------
# Chunk 482:
# . Its real -time posture feedback, personalized exercise
# recommendations, and user -centric design have led to tangible improvements in posture
# awareness, discomfort reduction
# ----------------------------------------
# Chunk 483:
# , and overall well -being for users
# ----------------------------------------
# Chunk 484:
# . By bridging the gap between
# technology and healthcare
# ----------------------------------------
# Chunk 485:
# , Physioflex has not only empowered individuals to  take proactive
# steps towards better posture but has also contributed to a broader conversation on preventive
# care, digital wellness
# ----------------------------------------
# Chunk 486:
# , digital wellness, and the integration of technology in promoting healthier lifestyles
# ----------------------------------------
# Chunk 487:
# .
# Looking ahead, Physio flex's commitment to continuous  innovation, user engagement, and
# collaborative partnerships ensures a future where musculoskeletal health management is
# accessible
# ----------------------------------------
# Chunk 488:
# , personalized, and impactful for users worldwide
# ----------------------------------------
# Chunk 489:
# .
#
# 7.2. Future Work
# 1. Invest in further research and development to improve th e accuracy, sensitivity, and
# specificity of posture detection algorithms used in Physioflex
# ----------------------------------------
# Chunk 490:
# . Explore machine learning
# techniques, data augmentation strategies, and sensor integration for more precise and
# comprehensive posture assessment.
# 2
# ----------------------------------------
# Chunk 491:
# . Explore innovativ e feedback mechanisms, such as augmented reality (A visualizations,
# haptic feedback, or gamification elements
# ----------------------------------------
# Chunk 492:
# , to enhance user engagement and effectiveness
# of posture correction cues)
# ----------------------------------------
# Chunk 493:
# .
# 3
# ----------------------------------------
# Chunk 494:
# . Personalized Exercise Recommendations: Expand the range of personalized  exercise
# recommendations in Physioflex, incorporating diverse exercises targeting specific
# musculoskeletal issues
# ----------------------------------------
# Chunk 495:
# , mobility challenges, and ergonomic adjustments
# ----------------------------------------
# Chunk 496:
# .
# 4
# ----------------------------------------
# Chunk 497:
# . Integration with Wearable Devices: Explore integration with wearable devices and sensors
# to capture real -time posture data, monitor physical activity levels
# ----------------------------------------
# Chunk 498:
# , and provide
# personalized feedback and reminders for posture correction throughout the day
# ----------------------------------------
# Chunk 499:
# .
# 5
# ----------------------------------------
# Chunk 500:
# . Data Analytic and Insights: Leverage data analytic and machine learning techniques to
# derive action able insights from user data collected by Physioflex, enabling personalized
# interventions
# ----------------------------------------
# Chunk 501:
# , trend analysis, and predictive modeling for musculoskeletal health
# outcomes
# ----------------------------------------
# Chunk 502:
# .
# 6
# ----------------------------------------
# Chunk 503:
# . Telehealth and Remote Monitoring: Explore opportunities for integrating Physioflex with
# telehealth platforms, enabling remote consultations, virtual coaching sessions
# ----------------------------------------
# Chunk 504:
# , and
# continuous monitoring of users' progress in posture correction and exercise adherence
# ----------------------------------------
# Chunk 505:
# .
# 7
# ----------------------------------------
# Chunk 506:
# . Accessibility and Inclusivity Features: Enhance Physio flex's accessibility features to cater
# to diverse user needs, including support for different languages
# ----------------------------------------
# Chunk 507:
# , accessibility settings for
# users with disabilities, and inclusive design principles for a broader user base
# ----------------------------------------
# Chunk 508:
# .
# 37
#  8
# ----------------------------------------
# Chunk 509:
# . Clinical Validation and Research Collaborations: Collaborate with health care institutions,
# research organizations, and clinical experts to validate the efficacy of Physioflex in clinical
# settings
# ----------------------------------------
# Chunk 510:
# , conduct longitudinal studies on posture improvement outcomes, and contribute
# to evidence based practices in musculoskeletal health
# ----------------------------------------
# Chunk 511:
# .
# 9
# ----------------------------------------
# Chunk 512:
# . User Engagement and Education Initiatives: Launching user engagement campaigns,
# educational materials, and community initiatives to raise awareness about musculoskeletal
# health
# ----------------------------------------
# Chunk 513:
# , promote healthy posture habits, and foster a supportive user community around
# Physioflex
# ----------------------------------------
# Chunk 514:
# .
# 10
# ----------------------------------------
# Chunk 515:
# . Scalability and Global Reach: Plan for scalability and global expansion of Physioflex,
# considering localization for different regions, compliance with international healthcare
# standards
# ----------------------------------------
# Chunk 516:
# , and scalability of infrastructure to accommodate growing  user populations
# ----------------------------------------
# Chunk 517:
# .
#
#
#
#
# 7.3. References
# i. https://play.google.com/store/apps/details?id=com.physitrack.physiapp HYPERLINK
# "https://play.google.com/store/apps/details?id=com.physitrack.physiapp&pli=1"
# ii
# ----------------------------------------
# Chunk 518:
# . https://www.usa.edu/blog/virtual -physical -therapy/
# iii. https://my.clevelandclinic.org/health/treatments/physical -therapy
# iv. https://www.virtualphysicaltherapists.com/
# ----------------------------------------

# %% [markdown]
# ### Recursively Splitting Text by Characters
# The idea behind recursively splitting text by characters is to break down large pieces of text into smaller, manageable chunks based on a specified set of characters (like periods, commas, etc.). This is important because some models might have a maximum token limit, so you want to ensure that each chunk is within those limits.
# here are the steps
# 1. Import the Required Splitter: LangChain provides a RecursiveCharacterTextSplitter class for this purpose.
#
# 2. Create an Instance of the Splitter: You can specify the set of characters you want to split by (e.g., periods, commas) and the maximum chunk size.
#
# 3. Split the Text: Use the splitter to split the loaded text into chunks.

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter=RecursiveCharacterTextSplitter(
    chunk_size=20,
    chunk_overlap=4,
    separators=["\n\n",".","!","?",","," ",""]
)
#load the document
document=loader()
# split doc into chunks
splited_text=splitter.split_documents(document)

# write a function to print all
print(f"number of chunks : {len(splited_text)}")

for i in splited_text:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       2 splitter=RecursiveCharacterTextSplitter(
#       3     chunk_size=20,
#       4     chunk_overlap=4,
#       5     separators=["\n\n",".","!","?",","," ",""]
#       6 )
#       7 #load the document
# ----> 8 document=loader()
#       9 # split doc into chunks
#      10 splited_text=splitter.split_documents(document)
#
# TypeError: 'list' object is not callable

# %% [markdown]
# ## How to split code

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

#loading python file
with open('app.py' , 'r') as file:
    code=file.read()
splitter = RecursiveCharacterTextSplitter(
    chunk_size=50,   # Adjust based on the size of your code chunks
    chunk_overlap=10,
    separators=["\n\n", "\n", ";", "}", "{", " "]
)

# Split the code into chunks
chunked_code = splitter.split_text(code)

# Output the number of chunks and a sample chunk
print(f"Number of chunks: {len(chunked_code)}")
for i in chunked_code:
    print("Chunk : ", i)
# Out:
# Number of chunks: 6
# Chunk :  def example_function():
#     for i in range(10):
# Chunk :  print(i)
#     return 'Done'
# Chunk :  class ExampleClass:
#     def __init__(self):
# Chunk :  self.value = 0
# Chunk :  def increment(self):
#         self.value += 1
# Chunk :  return self.value

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Define your Python code
PYTHON_CODE = """
def hello_world():
    print("Hello, World!")

    def add(a, b):
    return a + b
hello_world()
result = add(3, 5)
print(f"Result: {result}")
"""

# Create a RecursiveCharacterTextSplitter instance
python_splitter = RecursiveCharacterTextSplitter.from_language(
    language="python", 
    chunk_size=50, 
    chunk_overlap=10  # overlap between chunks to maintain context
)

# Split the code into chunks
chunks = python_splitter.split_text(PYTHON_CODE)
chunks
# Out:
# ['def hello_world():\n    print("Hello, World!")',
#  'def add(a, b):\n    return a + b',
#  'hello_world()\nresult = add(3, 5)',
#  'print(f"Result: {result}")']

# %% [markdown]
# Splitters Examples # 1

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter, CharacterTextSplitter

# %%
text="Once you've loaded documents, you'll often want to transform them to better suit your application. The simplest example is you may want to split a long document into smaller chunks that can fit into your model's context window"
r_splitter=RecursiveCharacterTextSplitter(
    chunk_size=20,
    separators=['\n','.',' ',],
    chunk_overlap=4
)
r_splitter.split_text(text)
# Out:
# ["Once you've loaded",
#  "documents, you'll",
#  'often want to',
#  'to transform them',
#  'to better suit your',
#  'application',
#  '. The simplest',
#  'example is you may',
#  'may want to split a',
#  'a long document',
#  'into smaller chunks',
#  'that can fit into',
#  "your model's",
#  'context window']

# %%
from langchain.text_splitter import CharacterTextSplitter

# Define the text to split
text = "This is an example. of how character .splitter works. This is the start.  "

# Create a CharacterTextSplitter instance
char_splitter = CharacterTextSplitter(
    chunk_size=25,
    separator='.',  # Corrected the typo
    chunk_overlap=3
)

# Split the text into chunks
chunks = char_splitter.split_text(text)

# Display the resulting chunks
chunks
# Out:
# ['This is an example',
#  'of how character',
#  'splitter works',
#  'This is the start.']
